# %%
from torch import nn
import torch.nn.functional as F
import numpy as np
import gym
import os

import torch
import json
import torch.nn as nn
import torch.nn.functional as F
from torch import nn, optim
import cv2

import random                 # Handling random number generation
import time                   # Handling time calculation
from skimage import transform # Help us to preprocess the frames

from collections import deque # Ordered collection with ends
import matplotlib.pyplot as plt  # Display graphs

import warnings                  # This ignore all the warning messages that are normally printed during the training because of skiimage
warnings.filterwarnings('ignore')

# %%
### MODEL HYPERPARAMETERS
learning_rate =  1e-5     

### TRAINING HYPERPARAMETERS
total_episodes = 100000         # Total episodes for training

batch_size = 128

# FIXED Q TARGETS HYPERPARAMETERS
update_steps = 4
clip_norm = 0.00008 
# EXPLORATION HYPERPARAMETERS for epsilon greedy strategy
explore_start = 0.1           # exploration probability at start
explore_stop = 0.001            # minimum exploration probability        # exponential decay rate for exploration prob
explore = 20000

model_path = f"./models/random_replay/CN{clip_norm}_LR{learning_rate}_B{batch_size}"
os.makedirs(model_path)
log_path = f"./logs/random_replay/CN{clip_norm}_LR{learning_rate}_B{batch_size}.txt"

# Q LEARNING hyperparameters
gamma = 0.99               # Discounting rate

### MEMORY HYPERPARAMETERS
## If you have GPU change to 1million
pretrain_length = 1000             # Number of experiences stored in the Memory when initialized for the first time
memory_size = 50000 ##100000                 # Number of experiences the Memory can keep

env = gym.make('CartPole-v1')

# %%
class DDDQNet(nn.Module):
    def __init__(self):
        super().__init__()

        self.fc1 = nn.Linear(4, 64)
        self.relu = nn.ReLU()

        self.fc_value = nn.Linear(64, 256)
        self.value = nn.Linear(256, 1)

        self.fc_adv = nn.Linear(64, 256)
        self.adv = nn.Linear(256, 2)

    def forward(self, x):
        y = self.relu(self.fc1(x))
        value = self.relu(self.fc_value(y))
        adv = self.relu(self.fc_adv(y))

        value = self.value(value)
        adv = self.adv(adv)

        output = value + adv - torch.mean(adv, dim=1, keepdim=True)

        return output

    def select_action(self, x):
        with torch.no_grad():
            Q = self.forward(x)
            action_index = torch.argmax(Q, dim=1)
        return action_index.item()
    



def update_target_params(PolicyNetwork, TargetNetwork):
    """
    Copy parameters of the Policy network to Target network.
    """
    TargetNetwork_state_dict = TargetNetwork.state_dict()
    PolicyNetwork_state_dict = PolicyNetwork.state_dict()
    for key in PolicyNetwork_state_dict:
        TargetNetwork_state_dict[key] = PolicyNetwork_state_dict[key]
        TargetNetwork.load_state_dict(TargetNetwork_state_dict)

    return PolicyNetwork, TargetNetwork   


class Memory(object):
    def __init__(self, memory_size: int) -> None:
        self.memory_size = memory_size
        self.buffer = deque(maxlen=self.memory_size)

    def add(self, experience) -> None:
        self.buffer.append(experience)

    def size(self):
        return len(self.buffer)

    def sample(self, batch_size: int, continuous: bool = True):
        if batch_size > len(self.buffer):
            batch_size = len(self.buffer)
        if continuous:
            rand = random.randint(0, len(self.buffer) - batch_size)
            return [self.buffer[i] for i in range(rand, rand + batch_size)]
        else:
            indexes = np.random.choice(np.arange(len(self.buffer)), size=batch_size, replace=False)
            return [self.buffer[i] for i in indexes]

    def clear(self):
        self.buffer.clear()

# %%
import random
# Instantiate memory
memory = Memory(memory_size)
import numpy as np 


env = gym.make('CartPole-v1')
n_state = env.observation_space.shape[0]  # 4
n_action = env.action_space.n

state, _ = env.reset()


for i in range(pretrain_length):
    
    action = random.randint(0,1)
    next_state, reward, done, _, _ = env.step(action)

    if done:
        next_state = np.zeros(n_state)
        experience = state, action, reward, next_state, done
        #print("shape of a stack frame of dead: ", state.shape)
        memory.add(experience)
        
        # Start a new episode
        state, _ = env.reset()
    else:
        experience = state, action, reward, next_state, done
        memory.add(experience)

        state = next_state

env.close()

# %%
# Instantiate the DQNetwork
PolicyNetwork = DDDQNet()

# Instantiate the target network
TargetNetwork = DDDQNet()

optimizer = optim.RMSprop(PolicyNetwork.parameters(), lr=learning_rate)

def select_action(epsilon, state):
    """
    This function will do the part
    With ϵ select a random action atat, otherwise select at=argmaxaQ(st,a)

    Input state is 4 stacked states. 
    """

    num = random.random()

    if (num < epsilon):
        action = random.randint(0, 1)
        return action
    # Greedy action
    else:
        
        tensor_state = torch.tensor(state, dtype=torch.float32).unsqueeze(0)
        action = PolicyNetwork.select_action(tensor_state)
        return action

epsilon = explore_start
# Set Target network params
PolicyNetwork, TargetNetwork = update_target_params(PolicyNetwork, TargetNetwork)

out_f = open(log_path, 'w')

env = gym.make('CartPole-v1')

total_steps = 0

for episode in range(total_episodes):

    episode_step = 0
    episode_reward = 0
    state, _ = env.reset()
    # print("state: ", state)
    

    for time_steps in range(10000):

        episode_step += 1
        total_steps += 1

        action = select_action(epsilon, state)
        next_state, reward, done, _, _ = env.step(action)

        episode_reward += reward

        if done: 
            next_state = np.zeros(n_state)
            experience = state, action, reward, next_state, done
            memory.add(experience)

        else: 
            experience = state, action, reward, next_state, done
            # print("state: ", state)
            memory.add(experience)
            state = next_state

        
        batch = memory.sample(batch_size, False)

        batch_states, batch_actions, batch_rewards, batch_next_states, batch_dones = zip(*batch)
        # state, action, reward, next_state, done
        # 
        # 

        batch_states = torch.FloatTensor(batch_states)
        batch_next_states = torch.FloatTensor(batch_next_states)
        batch_actions = torch.FloatTensor(batch_actions).unsqueeze(1)
        batch_rewards = torch.FloatTensor(batch_rewards).unsqueeze(1)
        batch_dones = torch.FloatTensor(batch_dones).unsqueeze(1)

        actions_index = batch_actions.detach().numpy().flatten()

        with torch.no_grad():
            policy_q_next = PolicyNetwork(batch_next_states)
            target_q_next = TargetNetwork(batch_next_states)
            online_max_action = torch.argmax(policy_q_next, dim=1, keepdim=True)
            y = batch_rewards + (1 - batch_dones) * gamma * target_q_next.gather(1, online_max_action.long())

        loss = F.mse_loss(PolicyNetwork(batch_states).gather(1, batch_actions.long()), y)
        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(PolicyNetwork.parameters(), clip_norm)
        optimizer.step()


        if epsilon > explore_stop:
            epsilon -= (explore_start - explore_stop) / explore

        # print("POLICY PARAMS: " , PolicyNetwork.state_dict())
        if total_steps % update_steps == 0:
            PolicyNetwork, TargetNetwork = update_target_params(PolicyNetwork, TargetNetwork)
            # print("Model updated")

        if done: 
            # Write batch stats to log files 
            loss_at_end_of_episode = loss.item()

            out_f.write(json.dumps({
                'episode': episode,
                'reward': episode_reward,
                'total_steps': total_steps,
                'length': episode_step,
                'loss': loss_at_end_of_episode,
                'epsilon': epsilon,
            }) + '\n')

            out_f.flush()
            

            print(f"Episode {episode}     |      Reward: {episode_reward}     |     length: {episode_step}      |      Loss: {loss_at_end_of_episode}    |     Total timesteps: {total_steps}")
        
            if episode % 100 == 0:
                torch.save(PolicyNetwork, f'{model_path}/E{episode}.pt')
                print(f"======Model saved.======")
            
            break

    if total_steps > 100000:
        break

env.close()
# Out:
# Episode 0     |      Reward: 76.0     |     length: 76      |      Loss: 1.0462478399276733    |     Total timesteps: 76
# ======Model saved.======
# Episode 1     |      Reward: 64.0     |     length: 64      |      Loss: 1.0304501056671143    |     Total timesteps: 140
# Episode 2     |      Reward: 43.0     |     length: 43      |      Loss: 1.038540005683899    |     Total timesteps: 183
# Episode 3     |      Reward: 49.0     |     length: 49      |      Loss: 1.0323675870895386    |     Total timesteps: 232
# Episode 4     |      Reward: 32.0     |     length: 32      |      Loss: 1.0333003997802734    |     Total timesteps: 264
# Episode 5     |      Reward: 52.0     |     length: 52      |      Loss: 1.0358635187149048    |     Total timesteps: 316
# Episode 6     |      Reward: 92.0     |     length: 92      |      Loss: 1.02664315700531    |     Total timesteps: 408
# Episode 7     |      Reward: 58.0     |     length: 58      |      Loss: 1.0401690006256104    |     Total timesteps: 466
# Episode 8     |      Reward: 43.0     |     length: 43      |      Loss: 1.0362142324447632    |     Total timesteps: 509
# Episode 9     |      Reward: 88.0     |     length: 88      |      Loss: 1.0278232097625732    |     Total timesteps: 597
# Episode 10     |      Reward: 60.0     |     length: 60      |      Loss: 1.0617742538452148    |     Total timesteps: 657
# Episode 11     |      Reward: 78.0     |     length: 78      |      Loss: 1.0917969942092896    |     Total timesteps: 735
# Episode 12     |      Reward: 79.0     |     length: 79      |      Loss: 1.0200823545455933    |     Total timesteps: 814
# Episode 13     |      Reward: 52.0     |     length: 52      |      Loss: 1.072129249572754    |     Total timesteps: 866
# Episode 14     |      Reward: 43.0     |     length: 43      |      Loss: 1.0577555894851685    |     Total timesteps: 909
# Episode 15     |      Reward: 40.0     |     length: 40      |      Loss: 1.0608080625534058    |     Total timesteps: 949
# Episode 16     |      Reward: 48.0     |     length: 48      |      Loss: 1.098344087600708    |     Total timesteps: 997
# Episode 17     |      Reward: 37.0     |     length: 37      |      Loss: 1.0664987564086914    |     Total timesteps: 1034
# Episode 18     |      Reward: 42.0     |     length: 42      |      Loss: 1.0814051628112793    |     Total timesteps: 1076
# Episode 19     |      Reward: 72.0     |     length: 72      |      Loss: 1.0227196216583252    |     Total timesteps: 1148
# Episode 20     |      Reward: 33.0     |     length: 33      |      Loss: 1.0439543724060059    |     Total timesteps: 1181
# Episode 21     |      Reward: 60.0     |     length: 60      |      Loss: 1.089062213897705    |     Total timesteps: 1241
# Episode 22     |      Reward: 45.0     |     length: 45      |      Loss: 1.0798871517181396    |     Total timesteps: 1286
# Episode 23     |      Reward: 53.0     |     length: 53      |      Loss: 1.070636510848999    |     Total timesteps: 1339
# Episode 24     |      Reward: 103.0     |     length: 103      |      Loss: 1.1010857820510864    |     Total timesteps: 1442
# Episode 25     |      Reward: 61.0     |     length: 61      |      Loss: 1.064476728439331    |     Total timesteps: 1503
# Episode 26     |      Reward: 48.0     |     length: 48      |      Loss: 1.0627729892730713    |     Total timesteps: 1551
# Episode 27     |      Reward: 60.0     |     length: 60      |      Loss: 1.1209337711334229    |     Total timesteps: 1611
# Episode 28     |      Reward: 64.0     |     length: 64      |      Loss: 1.0862140655517578    |     Total timesteps: 1675
# Episode 29     |      Reward: 37.0     |     length: 37      |      Loss: 1.0735996961593628    |     Total timesteps: 1712
# Episode 30     |      Reward: 54.0     |     length: 54      |      Loss: 1.141934871673584    |     Total timesteps: 1766
# Episode 31     |      Reward: 39.0     |     length: 39      |      Loss: 1.1179261207580566    |     Total timesteps: 1805
# Episode 32     |      Reward: 43.0     |     length: 43      |      Loss: 1.0905470848083496    |     Total timesteps: 1848
# Episode 33     |      Reward: 55.0     |     length: 55      |      Loss: 1.122427225112915    |     Total timesteps: 1903
# Episode 34     |      Reward: 45.0     |     length: 45      |      Loss: 1.132265567779541    |     Total timesteps: 1948
# Episode 35     |      Reward: 44.0     |     length: 44      |      Loss: 1.1039315462112427    |     Total timesteps: 1992
# Episode 36     |      Reward: 39.0     |     length: 39      |      Loss: 1.1614384651184082    |     Total timesteps: 2031
# Episode 37     |      Reward: 44.0     |     length: 44      |      Loss: 1.1036512851715088    |     Total timesteps: 2075
# Episode 38     |      Reward: 30.0     |     length: 30      |      Loss: 1.1531678438186646    |     Total timesteps: 2105
# Episode 39     |      Reward: 74.0     |     length: 74      |      Loss: 1.2556202411651611    |     Total timesteps: 2179
# Episode 40     |      Reward: 51.0     |     length: 51      |      Loss: 1.1356600522994995    |     Total timesteps: 2230
# Episode 41     |      Reward: 46.0     |     length: 46      |      Loss: 1.1356678009033203    |     Total timesteps: 2276
# Episode 42     |      Reward: 31.0     |     length: 31      |      Loss: 1.1181458234786987    |     Total timesteps: 2307
# Episode 43     |      Reward: 34.0     |     length: 34      |      Loss: 1.1532350778579712    |     Total timesteps: 2341
# Episode 44     |      Reward: 47.0     |     length: 47      |      Loss: 1.1129252910614014    |     Total timesteps: 2388
# Episode 45     |      Reward: 59.0     |     length: 59      |      Loss: 1.1323864459991455    |     Total timesteps: 2447
# Episode 46     |      Reward: 36.0     |     length: 36      |      Loss: 1.2492694854736328    |     Total timesteps: 2483
# Episode 47     |      Reward: 37.0     |     length: 37      |      Loss: 1.3752533197402954    |     Total timesteps: 2520
# Episode 48     |      Reward: 40.0     |     length: 40      |      Loss: 1.2639988660812378    |     Total timesteps: 2560
# Episode 49     |      Reward: 35.0     |     length: 35      |      Loss: 1.337693691253662    |     Total timesteps: 2595
# Episode 50     |      Reward: 27.0     |     length: 27      |      Loss: 1.3150602579116821    |     Total timesteps: 2622
# Episode 51     |      Reward: 38.0     |     length: 38      |      Loss: 1.3953831195831299    |     Total timesteps: 2660
# Episode 52     |      Reward: 28.0     |     length: 28      |      Loss: 1.3046822547912598    |     Total timesteps: 2688
# Episode 53     |      Reward: 61.0     |     length: 61      |      Loss: 1.2615077495574951    |     Total timesteps: 2749
# Episode 54     |      Reward: 40.0     |     length: 40      |      Loss: 1.2754504680633545    |     Total timesteps: 2789
# Episode 55     |      Reward: 46.0     |     length: 46      |      Loss: 1.3271275758743286    |     Total timesteps: 2835
# Episode 56     |      Reward: 62.0     |     length: 62      |      Loss: 1.2943860292434692    |     Total timesteps: 2897
# Episode 57     |      Reward: 44.0     |     length: 44      |      Loss: 1.2874215841293335    |     Total timesteps: 2941
# Episode 58     |      Reward: 55.0     |     length: 55      |      Loss: 1.5399874448776245    |     Total timesteps: 2996
# Episode 59     |      Reward: 37.0     |     length: 37      |      Loss: 1.2809094190597534    |     Total timesteps: 3033
# Episode 60     |      Reward: 29.0     |     length: 29      |      Loss: 1.3689979314804077    |     Total timesteps: 3062
# Episode 61     |      Reward: 49.0     |     length: 49      |      Loss: 1.8184373378753662    |     Total timesteps: 3111
# Episode 62     |      Reward: 36.0     |     length: 36      |      Loss: 1.6709418296813965    |     Total timesteps: 3147
# Episode 63     |      Reward: 37.0     |     length: 37      |      Loss: 1.2063333988189697    |     Total timesteps: 3184
# Episode 64     |      Reward: 43.0     |     length: 43      |      Loss: 1.6089911460876465    |     Total timesteps: 3227
# Episode 65     |      Reward: 40.0     |     length: 40      |      Loss: 1.1884021759033203    |     Total timesteps: 3267
# Episode 66     |      Reward: 26.0     |     length: 26      |      Loss: 2.064643621444702    |     Total timesteps: 3293
# Episode 67     |      Reward: 48.0     |     length: 48      |      Loss: 1.1868864297866821    |     Total timesteps: 3341
# Episode 68     |      Reward: 36.0     |     length: 36      |      Loss: 1.3340102434158325    |     Total timesteps: 3377
# Episode 69     |      Reward: 21.0     |     length: 21      |      Loss: 1.2860585451126099    |     Total timesteps: 3398
# Episode 70     |      Reward: 44.0     |     length: 44      |      Loss: 1.4971219301223755    |     Total timesteps: 3442
# Episode 71     |      Reward: 24.0     |     length: 24      |      Loss: 1.4619686603546143    |     Total timesteps: 3466
# Episode 72     |      Reward: 31.0     |     length: 31      |      Loss: 1.4147710800170898    |     Total timesteps: 3497
# Episode 73     |      Reward: 30.0     |     length: 30      |      Loss: 1.6523736715316772    |     Total timesteps: 3527
# Episode 74     |      Reward: 25.0     |     length: 25      |      Loss: 1.507594347000122    |     Total timesteps: 3552
# Episode 75     |      Reward: 34.0     |     length: 34      |      Loss: 1.1964759826660156    |     Total timesteps: 3586
# Episode 76     |      Reward: 25.0     |     length: 25      |      Loss: 1.2702592611312866    |     Total timesteps: 3611
# Episode 77     |      Reward: 24.0     |     length: 24      |      Loss: 1.4937974214553833    |     Total timesteps: 3635
# Episode 78     |      Reward: 28.0     |     length: 28      |      Loss: 1.2538076639175415    |     Total timesteps: 3663
# Episode 79     |      Reward: 30.0     |     length: 30      |      Loss: 1.348975419998169    |     Total timesteps: 3693
# Episode 80     |      Reward: 27.0     |     length: 27      |      Loss: 1.329566240310669    |     Total timesteps: 3720
# Episode 81     |      Reward: 31.0     |     length: 31      |      Loss: 1.954022765159607    |     Total timesteps: 3751
# Episode 82     |      Reward: 24.0     |     length: 24      |      Loss: 1.8896045684814453    |     Total timesteps: 3775
# Episode 83     |      Reward: 31.0     |     length: 31      |      Loss: 1.8285402059555054    |     Total timesteps: 3806
# Episode 84     |      Reward: 31.0     |     length: 31      |      Loss: 1.4129741191864014    |     Total timesteps: 3837
# Episode 85     |      Reward: 26.0     |     length: 26      |      Loss: 1.9160585403442383    |     Total timesteps: 3863
# Episode 86     |      Reward: 22.0     |     length: 22      |      Loss: 1.5246593952178955    |     Total timesteps: 3885
# Episode 87     |      Reward: 31.0     |     length: 31      |      Loss: 1.9958900213241577    |     Total timesteps: 3916
# Episode 88     |      Reward: 19.0     |     length: 19      |      Loss: 2.466892719268799    |     Total timesteps: 3935
# Episode 89     |      Reward: 26.0     |     length: 26      |      Loss: 1.432802677154541    |     Total timesteps: 3961
# Episode 90     |      Reward: 18.0     |     length: 18      |      Loss: 1.964667558670044    |     Total timesteps: 3979
# Episode 91     |      Reward: 30.0     |     length: 30      |      Loss: 1.236554741859436    |     Total timesteps: 4009
# Episode 92     |      Reward: 29.0     |     length: 29      |      Loss: 1.776877522468567    |     Total timesteps: 4038
# Episode 93     |      Reward: 18.0     |     length: 18      |      Loss: 2.119626522064209    |     Total timesteps: 4056
# Episode 94     |      Reward: 24.0     |     length: 24      |      Loss: 1.9815785884857178    |     Total timesteps: 4080
# Episode 95     |      Reward: 20.0     |     length: 20      |      Loss: 1.3914738893508911    |     Total timesteps: 4100
# Episode 96     |      Reward: 24.0     |     length: 24      |      Loss: 1.749808430671692    |     Total timesteps: 4124
# Episode 97     |      Reward: 24.0     |     length: 24      |      Loss: 2.1263587474823    |     Total timesteps: 4148
# Episode 98     |      Reward: 23.0     |     length: 23      |      Loss: 1.71231210231781    |     Total timesteps: 4171
# Episode 99     |      Reward: 19.0     |     length: 19      |      Loss: 2.051400661468506    |     Total timesteps: 4190
# Episode 100     |      Reward: 23.0     |     length: 23      |      Loss: 2.3820886611938477    |     Total timesteps: 4213
# ======Model saved.======
# Episode 101     |      Reward: 25.0     |     length: 25      |      Loss: 2.054908275604248    |     Total timesteps: 4238
# Episode 102     |      Reward: 19.0     |     length: 19      |      Loss: 2.0284628868103027    |     Total timesteps: 4257
# Episode 103     |      Reward: 18.0     |     length: 18      |      Loss: 2.1131513118743896    |     Total timesteps: 4275
# Episode 104     |      Reward: 16.0     |     length: 16      |      Loss: 1.389053463935852    |     Total timesteps: 4291
# Episode 105     |      Reward: 19.0     |     length: 19      |      Loss: 3.6802148818969727    |     Total timesteps: 4310
# Episode 106     |      Reward: 21.0     |     length: 21      |      Loss: 2.3455557823181152    |     Total timesteps: 4331
# Episode 107     |      Reward: 17.0     |     length: 17      |      Loss: 2.1457881927490234    |     Total timesteps: 4348
# Episode 108     |      Reward: 33.0     |     length: 33      |      Loss: 2.1975231170654297    |     Total timesteps: 4381
# Episode 109     |      Reward: 22.0     |     length: 22      |      Loss: 1.9418188333511353    |     Total timesteps: 4403
# Episode 110     |      Reward: 25.0     |     length: 25      |      Loss: 1.8920187950134277    |     Total timesteps: 4428
# Episode 111     |      Reward: 14.0     |     length: 14      |      Loss: 2.1488840579986572    |     Total timesteps: 4442
# Episode 112     |      Reward: 21.0     |     length: 21      |      Loss: 2.511176586151123    |     Total timesteps: 4463
# Episode 113     |      Reward: 21.0     |     length: 21      |      Loss: 2.0053412914276123    |     Total timesteps: 4484
# Episode 114     |      Reward: 15.0     |     length: 15      |      Loss: 1.9029392004013062    |     Total timesteps: 4499
# Episode 115     |      Reward: 15.0     |     length: 15      |      Loss: 3.1258151531219482    |     Total timesteps: 4514
# Episode 116     |      Reward: 14.0     |     length: 14      |      Loss: 2.8894925117492676    |     Total timesteps: 4528
# Episode 117     |      Reward: 15.0     |     length: 15      |      Loss: 1.5696256160736084    |     Total timesteps: 4543
# Episode 118     |      Reward: 15.0     |     length: 15      |      Loss: 1.7200608253479004    |     Total timesteps: 4558
# Episode 119     |      Reward: 11.0     |     length: 11      |      Loss: 2.907733201980591    |     Total timesteps: 4569
# Episode 120     |      Reward: 9.0     |     length: 9      |      Loss: 2.2356719970703125    |     Total timesteps: 4578
# Episode 121     |      Reward: 12.0     |     length: 12      |      Loss: 1.9343998432159424    |     Total timesteps: 4590
# Episode 122     |      Reward: 10.0     |     length: 10      |      Loss: 3.1391448974609375    |     Total timesteps: 4600
# Episode 123     |      Reward: 9.0     |     length: 9      |      Loss: 2.2600417137145996    |     Total timesteps: 4609
# Episode 124     |      Reward: 10.0     |     length: 10      |      Loss: 2.9093258380889893    |     Total timesteps: 4619
# Episode 125     |      Reward: 9.0     |     length: 9      |      Loss: 1.5449714660644531    |     Total timesteps: 4628
# Episode 126     |      Reward: 9.0     |     length: 9      |      Loss: 4.190385818481445    |     Total timesteps: 4637
# Episode 127     |      Reward: 10.0     |     length: 10      |      Loss: 2.4823436737060547    |     Total timesteps: 4647
# Episode 128     |      Reward: 10.0     |     length: 10      |      Loss: 3.5603175163269043    |     Total timesteps: 4657
# Episode 129     |      Reward: 10.0     |     length: 10      |      Loss: 3.5853676795959473    |     Total timesteps: 4667
# Episode 130     |      Reward: 10.0     |     length: 10      |      Loss: 3.672952175140381    |     Total timesteps: 4677
# Episode 131     |      Reward: 8.0     |     length: 8      |      Loss: 3.0780398845672607    |     Total timesteps: 4685
# Episode 132     |      Reward: 9.0     |     length: 9      |      Loss: 4.929416656494141    |     Total timesteps: 4694
# Episode 133     |      Reward: 13.0     |     length: 13      |      Loss: 2.4222798347473145    |     Total timesteps: 4707
# Episode 134     |      Reward: 9.0     |     length: 9      |      Loss: 3.1586852073669434    |     Total timesteps: 4716
# Episode 135     |      Reward: 9.0     |     length: 9      |      Loss: 2.0474679470062256    |     Total timesteps: 4725
# Episode 136     |      Reward: 10.0     |     length: 10      |      Loss: 4.340795040130615    |     Total timesteps: 4735
# Episode 137     |      Reward: 9.0     |     length: 9      |      Loss: 2.9406442642211914    |     Total timesteps: 4744
# Episode 138     |      Reward: 11.0     |     length: 11      |      Loss: 2.2337899208068848    |     Total timesteps: 4755
# Episode 139     |      Reward: 11.0     |     length: 11      |      Loss: 4.399656295776367    |     Total timesteps: 4766
# Episode 140     |      Reward: 9.0     |     length: 9      |      Loss: 3.1925580501556396    |     Total timesteps: 4775
# Episode 141     |      Reward: 10.0     |     length: 10      |      Loss: 3.94382381439209    |     Total timesteps: 4785
# Episode 142     |      Reward: 14.0     |     length: 14      |      Loss: 3.39813494682312    |     Total timesteps: 4799
# Episode 143     |      Reward: 10.0     |     length: 10      |      Loss: 3.502208709716797    |     Total timesteps: 4809
# Episode 144     |      Reward: 10.0     |     length: 10      |      Loss: 3.287513017654419    |     Total timesteps: 4819
# Episode 145     |      Reward: 9.0     |     length: 9      |      Loss: 3.6274735927581787    |     Total timesteps: 4828
# Episode 146     |      Reward: 10.0     |     length: 10      |      Loss: 2.6220223903656006    |     Total timesteps: 4838
# Episode 147     |      Reward: 9.0     |     length: 9      |      Loss: 3.116011381149292    |     Total timesteps: 4847
# Episode 148     |      Reward: 9.0     |     length: 9      |      Loss: 5.977478504180908    |     Total timesteps: 4856
# Episode 149     |      Reward: 11.0     |     length: 11      |      Loss: 2.5954201221466064    |     Total timesteps: 4867
# Episode 150     |      Reward: 11.0     |     length: 11      |      Loss: 7.5143890380859375    |     Total timesteps: 4878
# Episode 151     |      Reward: 10.0     |     length: 10      |      Loss: 3.785707712173462    |     Total timesteps: 4888
# Episode 152     |      Reward: 10.0     |     length: 10      |      Loss: 3.8349790573120117    |     Total timesteps: 4898
# Episode 153     |      Reward: 9.0     |     length: 9      |      Loss: 5.054827690124512    |     Total timesteps: 4907
# Episode 154     |      Reward: 10.0     |     length: 10      |      Loss: 3.2880444526672363    |     Total timesteps: 4917
# Episode 155     |      Reward: 9.0     |     length: 9      |      Loss: 2.372319221496582    |     Total timesteps: 4926
# Episode 156     |      Reward: 9.0     |     length: 9      |      Loss: 3.088322401046753    |     Total timesteps: 4935
# Episode 157     |      Reward: 10.0     |     length: 10      |      Loss: 4.146542549133301    |     Total timesteps: 4945
# Episode 158     |      Reward: 9.0     |     length: 9      |      Loss: 2.419905662536621    |     Total timesteps: 4954
# Episode 159     |      Reward: 9.0     |     length: 9      |      Loss: 3.463581085205078    |     Total timesteps: 4963
# Episode 160     |      Reward: 9.0     |     length: 9      |      Loss: 4.545997142791748    |     Total timesteps: 4972
# Episode 161     |      Reward: 9.0     |     length: 9      |      Loss: 3.1868205070495605    |     Total timesteps: 4981
# Episode 162     |      Reward: 10.0     |     length: 10      |      Loss: 2.7704412937164307    |     Total timesteps: 4991
# Episode 163     |      Reward: 9.0     |     length: 9      |      Loss: 2.604964256286621    |     Total timesteps: 5000
# Episode 164     |      Reward: 9.0     |     length: 9      |      Loss: 3.6456339359283447    |     Total timesteps: 5009
# Episode 165     |      Reward: 10.0     |     length: 10      |      Loss: 5.6896209716796875    |     Total timesteps: 5019
# Episode 166     |      Reward: 9.0     |     length: 9      |      Loss: 6.000815391540527    |     Total timesteps: 5028
# Episode 167     |      Reward: 9.0     |     length: 9      |      Loss: 4.919283390045166    |     Total timesteps: 5037
# Episode 168     |      Reward: 10.0     |     length: 10      |      Loss: 5.078478813171387    |     Total timesteps: 5047
# Episode 169     |      Reward: 10.0     |     length: 10      |      Loss: 4.381900787353516    |     Total timesteps: 5057
# Episode 170     |      Reward: 13.0     |     length: 13      |      Loss: 6.077465057373047    |     Total timesteps: 5070
# Episode 171     |      Reward: 9.0     |     length: 9      |      Loss: 5.240334987640381    |     Total timesteps: 5079
# Episode 172     |      Reward: 12.0     |     length: 12      |      Loss: 4.165885925292969    |     Total timesteps: 5091
# Episode 173     |      Reward: 10.0     |     length: 10      |      Loss: 4.254215240478516    |     Total timesteps: 5101
# Episode 174     |      Reward: 10.0     |     length: 10      |      Loss: 8.173606872558594    |     Total timesteps: 5111
# Episode 175     |      Reward: 11.0     |     length: 11      |      Loss: 6.422115802764893    |     Total timesteps: 5122
# Episode 176     |      Reward: 10.0     |     length: 10      |      Loss: 3.9069480895996094    |     Total timesteps: 5132
# Episode 177     |      Reward: 10.0     |     length: 10      |      Loss: 6.004693508148193    |     Total timesteps: 5142
# Episode 178     |      Reward: 10.0     |     length: 10      |      Loss: 6.627449989318848    |     Total timesteps: 5152
# Episode 179     |      Reward: 9.0     |     length: 9      |      Loss: 4.148606300354004    |     Total timesteps: 5161
# Episode 180     |      Reward: 10.0     |     length: 10      |      Loss: 2.9607489109039307    |     Total timesteps: 5171
# Episode 181     |      Reward: 10.0     |     length: 10      |      Loss: 7.358964920043945    |     Total timesteps: 5181
# Episode 182     |      Reward: 10.0     |     length: 10      |      Loss: 4.707030773162842    |     Total timesteps: 5191
# Episode 183     |      Reward: 10.0     |     length: 10      |      Loss: 8.487645149230957    |     Total timesteps: 5201
# Episode 184     |      Reward: 10.0     |     length: 10      |      Loss: 4.944941997528076    |     Total timesteps: 5211
# Episode 185     |      Reward: 10.0     |     length: 10      |      Loss: 4.079015731811523    |     Total timesteps: 5221
# Episode 186     |      Reward: 10.0     |     length: 10      |      Loss: 1.5938626527786255    |     Total timesteps: 5231
# Episode 187     |      Reward: 10.0     |     length: 10      |      Loss: 3.043773889541626    |     Total timesteps: 5241
# Episode 188     |      Reward: 9.0     |     length: 9      |      Loss: 8.705220222473145    |     Total timesteps: 5250
# Episode 189     |      Reward: 9.0     |     length: 9      |      Loss: 4.8895416259765625    |     Total timesteps: 5259
# Episode 190     |      Reward: 9.0     |     length: 9      |      Loss: 8.24355411529541    |     Total timesteps: 5268
# Episode 191     |      Reward: 13.0     |     length: 13      |      Loss: 3.91292405128479    |     Total timesteps: 5281
# Episode 192     |      Reward: 8.0     |     length: 8      |      Loss: 6.84960412979126    |     Total timesteps: 5289
# Episode 193     |      Reward: 9.0     |     length: 9      |      Loss: 6.48325777053833    |     Total timesteps: 5298
# Episode 194     |      Reward: 9.0     |     length: 9      |      Loss: 3.7510080337524414    |     Total timesteps: 5307
# Episode 195     |      Reward: 10.0     |     length: 10      |      Loss: 10.377022743225098    |     Total timesteps: 5317
# Episode 196     |      Reward: 8.0     |     length: 8      |      Loss: 5.787446022033691    |     Total timesteps: 5325
# Episode 197     |      Reward: 9.0     |     length: 9      |      Loss: 5.812876224517822    |     Total timesteps: 5334
# Episode 198     |      Reward: 8.0     |     length: 8      |      Loss: 7.594171524047852    |     Total timesteps: 5342
# Episode 199     |      Reward: 10.0     |     length: 10      |      Loss: 5.925205707550049    |     Total timesteps: 5352
# Episode 200     |      Reward: 12.0     |     length: 12      |      Loss: 10.629026412963867    |     Total timesteps: 5364
# ======Model saved.======
# Episode 201     |      Reward: 9.0     |     length: 9      |      Loss: 7.758670806884766    |     Total timesteps: 5373
# Episode 202     |      Reward: 9.0     |     length: 9      |      Loss: 4.62431001663208    |     Total timesteps: 5382
# Episode 203     |      Reward: 10.0     |     length: 10      |      Loss: 6.875303745269775    |     Total timesteps: 5392
# Episode 204     |      Reward: 10.0     |     length: 10      |      Loss: 6.5993123054504395    |     Total timesteps: 5402
# Episode 205     |      Reward: 9.0     |     length: 9      |      Loss: 7.866208553314209    |     Total timesteps: 5411
# Episode 206     |      Reward: 9.0     |     length: 9      |      Loss: 5.236023902893066    |     Total timesteps: 5420
# Episode 207     |      Reward: 15.0     |     length: 15      |      Loss: 6.565456390380859    |     Total timesteps: 5435
# Episode 208     |      Reward: 15.0     |     length: 15      |      Loss: 7.582119464874268    |     Total timesteps: 5450
# Episode 209     |      Reward: 15.0     |     length: 15      |      Loss: 6.709722995758057    |     Total timesteps: 5465
# Episode 210     |      Reward: 21.0     |     length: 21      |      Loss: 8.784547805786133    |     Total timesteps: 5486
# Episode 211     |      Reward: 16.0     |     length: 16      |      Loss: 5.8605732917785645    |     Total timesteps: 5502
# Episode 212     |      Reward: 20.0     |     length: 20      |      Loss: 4.920285701751709    |     Total timesteps: 5522
# Episode 213     |      Reward: 29.0     |     length: 29      |      Loss: 10.945556640625    |     Total timesteps: 5551
# Episode 214     |      Reward: 18.0     |     length: 18      |      Loss: 6.485206604003906    |     Total timesteps: 5569
# Episode 215     |      Reward: 23.0     |     length: 23      |      Loss: 7.518174648284912    |     Total timesteps: 5592
# Episode 216     |      Reward: 15.0     |     length: 15      |      Loss: 4.37921667098999    |     Total timesteps: 5607
# Episode 217     |      Reward: 21.0     |     length: 21      |      Loss: 4.489291191101074    |     Total timesteps: 5628
# Episode 218     |      Reward: 17.0     |     length: 17      |      Loss: 5.909295082092285    |     Total timesteps: 5645
# Episode 219     |      Reward: 22.0     |     length: 22      |      Loss: 4.022276878356934    |     Total timesteps: 5667
# Episode 220     |      Reward: 23.0     |     length: 23      |      Loss: 7.746964931488037    |     Total timesteps: 5690
# Episode 221     |      Reward: 23.0     |     length: 23      |      Loss: 10.963848114013672    |     Total timesteps: 5713
# Episode 222     |      Reward: 15.0     |     length: 15      |      Loss: 6.582701206207275    |     Total timesteps: 5728
# Episode 223     |      Reward: 19.0     |     length: 19      |      Loss: 7.04564094543457    |     Total timesteps: 5747
# Episode 224     |      Reward: 19.0     |     length: 19      |      Loss: 6.958641052246094    |     Total timesteps: 5766
# Episode 225     |      Reward: 17.0     |     length: 17      |      Loss: 2.133840322494507    |     Total timesteps: 5783
# Episode 226     |      Reward: 23.0     |     length: 23      |      Loss: 8.525177955627441    |     Total timesteps: 5806
# Episode 227     |      Reward: 23.0     |     length: 23      |      Loss: 12.090141296386719    |     Total timesteps: 5829
# Episode 228     |      Reward: 12.0     |     length: 12      |      Loss: 6.170553684234619    |     Total timesteps: 5841
# Episode 229     |      Reward: 19.0     |     length: 19      |      Loss: 5.511223793029785    |     Total timesteps: 5860
# Episode 230     |      Reward: 17.0     |     length: 17      |      Loss: 5.269414901733398    |     Total timesteps: 5877
# Episode 231     |      Reward: 20.0     |     length: 20      |      Loss: 4.881252288818359    |     Total timesteps: 5897
# Episode 232     |      Reward: 17.0     |     length: 17      |      Loss: 7.369170665740967    |     Total timesteps: 5914
# Episode 233     |      Reward: 18.0     |     length: 18      |      Loss: 10.094429969787598    |     Total timesteps: 5932
# Episode 234     |      Reward: 15.0     |     length: 15      |      Loss: 12.3440523147583    |     Total timesteps: 5947
# Episode 235     |      Reward: 14.0     |     length: 14      |      Loss: 3.9633469581604004    |     Total timesteps: 5961
# Episode 236     |      Reward: 22.0     |     length: 22      |      Loss: 3.103008508682251    |     Total timesteps: 5983
# Episode 237     |      Reward: 15.0     |     length: 15      |      Loss: 6.393678665161133    |     Total timesteps: 5998
# Episode 238     |      Reward: 23.0     |     length: 23      |      Loss: 6.40498161315918    |     Total timesteps: 6021
# Episode 239     |      Reward: 13.0     |     length: 13      |      Loss: 6.659526348114014    |     Total timesteps: 6034
# Episode 240     |      Reward: 12.0     |     length: 12      |      Loss: 5.236910343170166    |     Total timesteps: 6046
# Episode 241     |      Reward: 17.0     |     length: 17      |      Loss: 4.648090362548828    |     Total timesteps: 6063
# Episode 242     |      Reward: 17.0     |     length: 17      |      Loss: 5.278265476226807    |     Total timesteps: 6080
# Episode 243     |      Reward: 17.0     |     length: 17      |      Loss: 5.858381271362305    |     Total timesteps: 6097
# Episode 244     |      Reward: 19.0     |     length: 19      |      Loss: 9.428251266479492    |     Total timesteps: 6116
# Episode 245     |      Reward: 14.0     |     length: 14      |      Loss: 7.281540870666504    |     Total timesteps: 6130
# Episode 246     |      Reward: 16.0     |     length: 16      |      Loss: 6.975485324859619    |     Total timesteps: 6146
# Episode 247     |      Reward: 12.0     |     length: 12      |      Loss: 7.957281112670898    |     Total timesteps: 6158
# Episode 248     |      Reward: 17.0     |     length: 17      |      Loss: 6.034173011779785    |     Total timesteps: 6175
# Episode 249     |      Reward: 13.0     |     length: 13      |      Loss: 7.251346588134766    |     Total timesteps: 6188
# Episode 250     |      Reward: 18.0     |     length: 18      |      Loss: 10.594600677490234    |     Total timesteps: 6206
# Episode 251     |      Reward: 20.0     |     length: 20      |      Loss: 11.942913055419922    |     Total timesteps: 6226
# Episode 252     |      Reward: 16.0     |     length: 16      |      Loss: 12.854120254516602    |     Total timesteps: 6242
# Episode 253     |      Reward: 18.0     |     length: 18      |      Loss: 11.433116912841797    |     Total timesteps: 6260
# Episode 254     |      Reward: 18.0     |     length: 18      |      Loss: 13.528690338134766    |     Total timesteps: 6278
# Episode 255     |      Reward: 15.0     |     length: 15      |      Loss: 4.069155216217041    |     Total timesteps: 6293
# Episode 256     |      Reward: 18.0     |     length: 18      |      Loss: 11.143638610839844    |     Total timesteps: 6311
# Episode 257     |      Reward: 15.0     |     length: 15      |      Loss: 6.823419570922852    |     Total timesteps: 6326
# Episode 258     |      Reward: 18.0     |     length: 18      |      Loss: 11.580438613891602    |     Total timesteps: 6344
# Episode 259     |      Reward: 16.0     |     length: 16      |      Loss: 10.266833305358887    |     Total timesteps: 6360
# Episode 260     |      Reward: 17.0     |     length: 17      |      Loss: 7.567046642303467    |     Total timesteps: 6377
# Episode 261     |      Reward: 23.0     |     length: 23      |      Loss: 9.11017894744873    |     Total timesteps: 6400
# Episode 262     |      Reward: 13.0     |     length: 13      |      Loss: 7.306683540344238    |     Total timesteps: 6413
# Episode 263     |      Reward: 18.0     |     length: 18      |      Loss: 12.433990478515625    |     Total timesteps: 6431
# Episode 264     |      Reward: 15.0     |     length: 15      |      Loss: 6.064877033233643    |     Total timesteps: 6446
# Episode 265     |      Reward: 13.0     |     length: 13      |      Loss: 6.062307357788086    |     Total timesteps: 6459
# Episode 266     |      Reward: 19.0     |     length: 19      |      Loss: 10.471048355102539    |     Total timesteps: 6478
# Episode 267     |      Reward: 15.0     |     length: 15      |      Loss: 6.919835090637207    |     Total timesteps: 6493
# Episode 268     |      Reward: 15.0     |     length: 15      |      Loss: 4.174890041351318    |     Total timesteps: 6508
# Episode 269     |      Reward: 13.0     |     length: 13      |      Loss: 9.002827644348145    |     Total timesteps: 6521
# Episode 270     |      Reward: 18.0     |     length: 18      |      Loss: 7.592047214508057    |     Total timesteps: 6539
# Episode 271     |      Reward: 16.0     |     length: 16      |      Loss: 4.624250411987305    |     Total timesteps: 6555
# Episode 272     |      Reward: 16.0     |     length: 16      |      Loss: 6.0406904220581055    |     Total timesteps: 6571
# Episode 273     |      Reward: 16.0     |     length: 16      |      Loss: 12.787995338439941    |     Total timesteps: 6587
# Episode 274     |      Reward: 14.0     |     length: 14      |      Loss: 3.3060882091522217    |     Total timesteps: 6601
# Episode 275     |      Reward: 16.0     |     length: 16      |      Loss: 8.261730194091797    |     Total timesteps: 6617
# Episode 276     |      Reward: 18.0     |     length: 18      |      Loss: 8.03373908996582    |     Total timesteps: 6635
# Episode 277     |      Reward: 16.0     |     length: 16      |      Loss: 6.7365336418151855    |     Total timesteps: 6651
# Episode 278     |      Reward: 17.0     |     length: 17      |      Loss: 5.405101299285889    |     Total timesteps: 6668
# Episode 279     |      Reward: 12.0     |     length: 12      |      Loss: 8.940938949584961    |     Total timesteps: 6680
# Episode 280     |      Reward: 18.0     |     length: 18      |      Loss: 10.611949920654297    |     Total timesteps: 6698
# Episode 281     |      Reward: 14.0     |     length: 14      |      Loss: 6.148667812347412    |     Total timesteps: 6712
# Episode 282     |      Reward: 19.0     |     length: 19      |      Loss: 13.068121910095215    |     Total timesteps: 6731
# Episode 283     |      Reward: 13.0     |     length: 13      |      Loss: 5.558599948883057    |     Total timesteps: 6744
# Episode 284     |      Reward: 14.0     |     length: 14      |      Loss: 13.313898086547852    |     Total timesteps: 6758
# Episode 285     |      Reward: 14.0     |     length: 14      |      Loss: 14.285117149353027    |     Total timesteps: 6772
# Episode 286     |      Reward: 14.0     |     length: 14      |      Loss: 7.816403388977051    |     Total timesteps: 6786
# Episode 287     |      Reward: 12.0     |     length: 12      |      Loss: 9.639297485351562    |     Total timesteps: 6798
# Episode 288     |      Reward: 14.0     |     length: 14      |      Loss: 17.279680252075195    |     Total timesteps: 6812
# Episode 289     |      Reward: 17.0     |     length: 17      |      Loss: 12.594773292541504    |     Total timesteps: 6829
# Episode 290     |      Reward: 18.0     |     length: 18      |      Loss: 7.2930450439453125    |     Total timesteps: 6847
# Episode 291     |      Reward: 13.0     |     length: 13      |      Loss: 3.92525053024292    |     Total timesteps: 6860
# Episode 292     |      Reward: 16.0     |     length: 16      |      Loss: 7.483722686767578    |     Total timesteps: 6876
# Episode 293     |      Reward: 12.0     |     length: 12      |      Loss: 6.963887691497803    |     Total timesteps: 6888
# Episode 294     |      Reward: 17.0     |     length: 17      |      Loss: 4.7587504386901855    |     Total timesteps: 6905
# Episode 295     |      Reward: 14.0     |     length: 14      |      Loss: 7.559837818145752    |     Total timesteps: 6919
# Episode 296     |      Reward: 14.0     |     length: 14      |      Loss: 13.529071807861328    |     Total timesteps: 6933
# Episode 297     |      Reward: 16.0     |     length: 16      |      Loss: 8.896512985229492    |     Total timesteps: 6949
# Episode 298     |      Reward: 12.0     |     length: 12      |      Loss: 12.67074966430664    |     Total timesteps: 6961
# Episode 299     |      Reward: 18.0     |     length: 18      |      Loss: 8.574366569519043    |     Total timesteps: 6979
# Episode 300     |      Reward: 14.0     |     length: 14      |      Loss: 7.01529598236084    |     Total timesteps: 6993
# ======Model saved.======
# Episode 301     |      Reward: 15.0     |     length: 15      |      Loss: 10.614917755126953    |     Total timesteps: 7008
# Episode 302     |      Reward: 14.0     |     length: 14      |      Loss: 13.055789947509766    |     Total timesteps: 7022
# Episode 303     |      Reward: 17.0     |     length: 17      |      Loss: 6.108677387237549    |     Total timesteps: 7039
# Episode 304     |      Reward: 14.0     |     length: 14      |      Loss: 10.125428199768066    |     Total timesteps: 7053
# Episode 305     |      Reward: 14.0     |     length: 14      |      Loss: 10.89739990234375    |     Total timesteps: 7067
# Episode 306     |      Reward: 20.0     |     length: 20      |      Loss: 13.092059135437012    |     Total timesteps: 7087
# Episode 307     |      Reward: 14.0     |     length: 14      |      Loss: 17.668031692504883    |     Total timesteps: 7101
# Episode 308     |      Reward: 19.0     |     length: 19      |      Loss: 3.4068164825439453    |     Total timesteps: 7120
# Episode 309     |      Reward: 19.0     |     length: 19      |      Loss: 14.798990249633789    |     Total timesteps: 7139
# Episode 310     |      Reward: 16.0     |     length: 16      |      Loss: 5.888207912445068    |     Total timesteps: 7155
# Episode 311     |      Reward: 20.0     |     length: 20      |      Loss: 17.324317932128906    |     Total timesteps: 7175
# Episode 312     |      Reward: 14.0     |     length: 14      |      Loss: 13.62193489074707    |     Total timesteps: 7189
# Episode 313     |      Reward: 17.0     |     length: 17      |      Loss: 10.559290885925293    |     Total timesteps: 7206
# Episode 314     |      Reward: 20.0     |     length: 20      |      Loss: 7.824530124664307    |     Total timesteps: 7226
# Episode 315     |      Reward: 13.0     |     length: 13      |      Loss: 11.463274002075195    |     Total timesteps: 7239
# Episode 316     |      Reward: 17.0     |     length: 17      |      Loss: 11.640856742858887    |     Total timesteps: 7256
# Episode 317     |      Reward: 14.0     |     length: 14      |      Loss: 7.477139949798584    |     Total timesteps: 7270
# Episode 318     |      Reward: 19.0     |     length: 19      |      Loss: 13.337071418762207    |     Total timesteps: 7289
# Episode 319     |      Reward: 14.0     |     length: 14      |      Loss: 15.6201171875    |     Total timesteps: 7303
# Episode 320     |      Reward: 18.0     |     length: 18      |      Loss: 5.361050128936768    |     Total timesteps: 7321
# Episode 321     |      Reward: 15.0     |     length: 15      |      Loss: 8.806098937988281    |     Total timesteps: 7336
# Episode 322     |      Reward: 22.0     |     length: 22      |      Loss: 10.315190315246582    |     Total timesteps: 7358
# Episode 323     |      Reward: 16.0     |     length: 16      |      Loss: 7.876962184906006    |     Total timesteps: 7374
# Episode 324     |      Reward: 18.0     |     length: 18      |      Loss: 9.642399787902832    |     Total timesteps: 7392
# Episode 325     |      Reward: 21.0     |     length: 21      |      Loss: 3.4133403301239014    |     Total timesteps: 7413
# Episode 326     |      Reward: 14.0     |     length: 14      |      Loss: 3.4920332431793213    |     Total timesteps: 7427
# Episode 327     |      Reward: 15.0     |     length: 15      |      Loss: 5.951264381408691    |     Total timesteps: 7442
# Episode 328     |      Reward: 16.0     |     length: 16      |      Loss: 5.370757102966309    |     Total timesteps: 7458
# Episode 329     |      Reward: 19.0     |     length: 19      |      Loss: 19.448442459106445    |     Total timesteps: 7477
# Episode 330     |      Reward: 19.0     |     length: 19      |      Loss: 6.416077613830566    |     Total timesteps: 7496
# Episode 331     |      Reward: 11.0     |     length: 11      |      Loss: 6.80454158782959    |     Total timesteps: 7507
# Episode 332     |      Reward: 12.0     |     length: 12      |      Loss: 7.550129413604736    |     Total timesteps: 7519
# Episode 333     |      Reward: 11.0     |     length: 11      |      Loss: 18.812732696533203    |     Total timesteps: 7530
# Episode 334     |      Reward: 17.0     |     length: 17      |      Loss: 17.013456344604492    |     Total timesteps: 7547
# Episode 335     |      Reward: 20.0     |     length: 20      |      Loss: 6.52324104309082    |     Total timesteps: 7567
# Episode 336     |      Reward: 16.0     |     length: 16      |      Loss: 11.919328689575195    |     Total timesteps: 7583
# Episode 337     |      Reward: 18.0     |     length: 18      |      Loss: 13.172472953796387    |     Total timesteps: 7601
# Episode 338     |      Reward: 14.0     |     length: 14      |      Loss: 14.156814575195312    |     Total timesteps: 7615
# Episode 339     |      Reward: 16.0     |     length: 16      |      Loss: 9.81761646270752    |     Total timesteps: 7631
# Episode 340     |      Reward: 12.0     |     length: 12      |      Loss: 13.69784164428711    |     Total timesteps: 7643
# Episode 341     |      Reward: 19.0     |     length: 19      |      Loss: 10.875097274780273    |     Total timesteps: 7662
# Episode 342     |      Reward: 12.0     |     length: 12      |      Loss: 16.505430221557617    |     Total timesteps: 7674
# Episode 343     |      Reward: 12.0     |     length: 12      |      Loss: 20.20634651184082    |     Total timesteps: 7686
# Episode 344     |      Reward: 12.0     |     length: 12      |      Loss: 11.96084213256836    |     Total timesteps: 7698
# Episode 345     |      Reward: 16.0     |     length: 16      |      Loss: 8.716019630432129    |     Total timesteps: 7714
# Episode 346     |      Reward: 16.0     |     length: 16      |      Loss: 9.101910591125488    |     Total timesteps: 7730
# Episode 347     |      Reward: 16.0     |     length: 16      |      Loss: 10.44961929321289    |     Total timesteps: 7746
# Episode 348     |      Reward: 16.0     |     length: 16      |      Loss: 9.206398010253906    |     Total timesteps: 7762
# Episode 349     |      Reward: 17.0     |     length: 17      |      Loss: 16.277780532836914    |     Total timesteps: 7779
# Episode 350     |      Reward: 18.0     |     length: 18      |      Loss: 14.765685081481934    |     Total timesteps: 7797
# Episode 351     |      Reward: 16.0     |     length: 16      |      Loss: 10.93995475769043    |     Total timesteps: 7813
# Episode 352     |      Reward: 13.0     |     length: 13      |      Loss: 8.662816047668457    |     Total timesteps: 7826
# Episode 353     |      Reward: 13.0     |     length: 13      |      Loss: 12.298123359680176    |     Total timesteps: 7839
# Episode 354     |      Reward: 12.0     |     length: 12      |      Loss: 14.651772499084473    |     Total timesteps: 7851
# Episode 355     |      Reward: 16.0     |     length: 16      |      Loss: 18.011110305786133    |     Total timesteps: 7867
# Episode 356     |      Reward: 15.0     |     length: 15      |      Loss: 8.644248962402344    |     Total timesteps: 7882
# Episode 357     |      Reward: 16.0     |     length: 16      |      Loss: 6.026230335235596    |     Total timesteps: 7898
# Episode 358     |      Reward: 18.0     |     length: 18      |      Loss: 4.522298812866211    |     Total timesteps: 7916
# Episode 359     |      Reward: 17.0     |     length: 17      |      Loss: 11.575945854187012    |     Total timesteps: 7933
# Episode 360     |      Reward: 12.0     |     length: 12      |      Loss: 6.409002304077148    |     Total timesteps: 7945
# Episode 361     |      Reward: 17.0     |     length: 17      |      Loss: 11.06594181060791    |     Total timesteps: 7962
# Episode 362     |      Reward: 20.0     |     length: 20      |      Loss: 17.663747787475586    |     Total timesteps: 7982
# Episode 363     |      Reward: 12.0     |     length: 12      |      Loss: 6.850458145141602    |     Total timesteps: 7994
# Episode 364     |      Reward: 12.0     |     length: 12      |      Loss: 7.407486915588379    |     Total timesteps: 8006
# Episode 365     |      Reward: 12.0     |     length: 12      |      Loss: 7.307459831237793    |     Total timesteps: 8018
# Episode 366     |      Reward: 13.0     |     length: 13      |      Loss: 6.41168737411499    |     Total timesteps: 8031
# Episode 367     |      Reward: 16.0     |     length: 16      |      Loss: 15.551441192626953    |     Total timesteps: 8047
# Episode 368     |      Reward: 16.0     |     length: 16      |      Loss: 13.074772834777832    |     Total timesteps: 8063
# Episode 369     |      Reward: 13.0     |     length: 13      |      Loss: 11.87802791595459    |     Total timesteps: 8076
# Episode 370     |      Reward: 17.0     |     length: 17      |      Loss: 13.584710121154785    |     Total timesteps: 8093
# Episode 371     |      Reward: 14.0     |     length: 14      |      Loss: 9.673521041870117    |     Total timesteps: 8107
# Episode 372     |      Reward: 15.0     |     length: 15      |      Loss: 4.651322841644287    |     Total timesteps: 8122
# Episode 373     |      Reward: 14.0     |     length: 14      |      Loss: 14.876996994018555    |     Total timesteps: 8136
# Episode 374     |      Reward: 10.0     |     length: 10      |      Loss: 6.185541152954102    |     Total timesteps: 8146
# Episode 375     |      Reward: 15.0     |     length: 15      |      Loss: 13.968378067016602    |     Total timesteps: 8161
# Episode 376     |      Reward: 12.0     |     length: 12      |      Loss: 11.471123695373535    |     Total timesteps: 8173
# Episode 377     |      Reward: 12.0     |     length: 12      |      Loss: 11.984715461730957    |     Total timesteps: 8185
# Episode 378     |      Reward: 12.0     |     length: 12      |      Loss: 6.153282642364502    |     Total timesteps: 8197
# Episode 379     |      Reward: 13.0     |     length: 13      |      Loss: 10.116556167602539    |     Total timesteps: 8210
# Episode 380     |      Reward: 15.0     |     length: 15      |      Loss: 20.754474639892578    |     Total timesteps: 8225
# Episode 381     |      Reward: 12.0     |     length: 12      |      Loss: 21.207157135009766    |     Total timesteps: 8237
# Episode 382     |      Reward: 9.0     |     length: 9      |      Loss: 11.917621612548828    |     Total timesteps: 8246
# Episode 383     |      Reward: 13.0     |     length: 13      |      Loss: 8.311840057373047    |     Total timesteps: 8259
# Episode 384     |      Reward: 13.0     |     length: 13      |      Loss: 18.905054092407227    |     Total timesteps: 8272
# Episode 385     |      Reward: 11.0     |     length: 11      |      Loss: 11.183747291564941    |     Total timesteps: 8283
# ...
# Episode 1455     |      Reward: 76.0     |     length: 76      |      Loss: 10.087291717529297    |     Total timesteps: 63780
# Episode 1456     |      Reward: 105.0     |     length: 105      |      Loss: 7.6430816650390625    |     Total timesteps: 63885
# Episode 1457     |      Reward: 161.0     |     length: 161      |      Loss: 0.6637136340141296    |     Total timesteps: 64046
# Episode 1458     |      Reward: 78.0     |     length: 78      |      Loss: 11.347210884094238    |     Total timesteps: 64124
# Episode 1459     |      Reward: 81.0     |     length: 81      |      Loss: 25.456233978271484    |     Total timesteps: 64205
# Episode 1460     |      Reward: 80.0     |     length: 80      |      Loss: 2.5679545402526855    |     Total timesteps: 64285
# Episode 1461     |      Reward: 86.0     |     length: 86      |      Loss: 6.321190357208252    |     Total timesteps: 64371
# Episode 1462     |      Reward: 97.0     |     length: 97      |      Loss: 48.76187515258789    |     Total timesteps: 64468
# Episode 1463     |      Reward: 122.0     |     length: 122      |      Loss: 24.287033081054688    |     Total timesteps: 64590
# Episode 1464     |      Reward: 91.0     |     length: 91      |      Loss: 0.7051147818565369    |     Total timesteps: 64681
# Episode 1465     |      Reward: 86.0     |     length: 86      |      Loss: 9.593484878540039    |     Total timesteps: 64767
# Episode 1466     |      Reward: 116.0     |     length: 116      |      Loss: 2.106393337249756    |     Total timesteps: 64883
# Episode 1467     |      Reward: 78.0     |     length: 78      |      Loss: 0.5708998441696167    |     Total timesteps: 64961
# Episode 1468     |      Reward: 89.0     |     length: 89      |      Loss: 5.568110942840576    |     Total timesteps: 65050
# Episode 1469     |      Reward: 86.0     |     length: 86      |      Loss: 0.45443814992904663    |     Total timesteps: 65136
# Episode 1470     |      Reward: 73.0     |     length: 73      |      Loss: 25.179458618164062    |     Total timesteps: 65209
# Episode 1471     |      Reward: 335.0     |     length: 335      |      Loss: 12.416857719421387    |     Total timesteps: 65544
# Episode 1472     |      Reward: 124.0     |     length: 124      |      Loss: 7.173589706420898    |     Total timesteps: 65668
# Episode 1473     |      Reward: 103.0     |     length: 103      |      Loss: 1.6859662532806396    |     Total timesteps: 65771
# Episode 1474     |      Reward: 147.0     |     length: 147      |      Loss: 0.42348405718803406    |     Total timesteps: 65918
# Episode 1475     |      Reward: 84.0     |     length: 84      |      Loss: 5.491519451141357    |     Total timesteps: 66002
# Episode 1476     |      Reward: 104.0     |     length: 104      |      Loss: 20.147863388061523    |     Total timesteps: 66106
# Episode 1477     |      Reward: 77.0     |     length: 77      |      Loss: 2.999685525894165    |     Total timesteps: 66183
# Episode 1478     |      Reward: 98.0     |     length: 98      |      Loss: 10.144879341125488    |     Total timesteps: 66281
# Episode 1479     |      Reward: 156.0     |     length: 156      |      Loss: 24.766633987426758    |     Total timesteps: 66437
# Episode 1480     |      Reward: 181.0     |     length: 181      |      Loss: 13.449353218078613    |     Total timesteps: 66618
# Episode 1481     |      Reward: 358.0     |     length: 358      |      Loss: 2.660147190093994    |     Total timesteps: 66976
# Episode 1482     |      Reward: 86.0     |     length: 86      |      Loss: 4.211328506469727    |     Total timesteps: 67062
# Episode 1483     |      Reward: 154.0     |     length: 154      |      Loss: 4.566947937011719    |     Total timesteps: 67216
# Episode 1484     |      Reward: 118.0     |     length: 118      |      Loss: 14.202104568481445    |     Total timesteps: 67334
# Episode 1485     |      Reward: 86.0     |     length: 86      |      Loss: 0.30045461654663086    |     Total timesteps: 67420
# Episode 1486     |      Reward: 165.0     |     length: 165      |      Loss: 0.41010814905166626    |     Total timesteps: 67585
# Episode 1487     |      Reward: 245.0     |     length: 245      |      Loss: 2.0285489559173584    |     Total timesteps: 67830
# Episode 1488     |      Reward: 112.0     |     length: 112      |      Loss: 0.48483923077583313    |     Total timesteps: 67942
# Episode 1489     |      Reward: 203.0     |     length: 203      |      Loss: 14.002079963684082    |     Total timesteps: 68145
# Episode 1490     |      Reward: 628.0     |     length: 628      |      Loss: 1.1751708984375    |     Total timesteps: 68773
# Episode 1491     |      Reward: 429.0     |     length: 429      |      Loss: 0.6671479940414429    |     Total timesteps: 69202
# Episode 1492     |      Reward: 243.0     |     length: 243      |      Loss: 6.378444194793701    |     Total timesteps: 69445
# Episode 1493     |      Reward: 117.0     |     length: 117      |      Loss: 0.4642122983932495    |     Total timesteps: 69562
# Episode 1494     |      Reward: 397.0     |     length: 397      |      Loss: 0.8633085489273071    |     Total timesteps: 69959
# Episode 1495     |      Reward: 278.0     |     length: 278      |      Loss: 4.8256144523620605    |     Total timesteps: 70237
# Episode 1496     |      Reward: 517.0     |     length: 517      |      Loss: 2.8602874279022217    |     Total timesteps: 70754
# Episode 1497     |      Reward: 347.0     |     length: 347      |      Loss: 3.5094423294067383    |     Total timesteps: 71101
# Episode 1498     |      Reward: 114.0     |     length: 114      |      Loss: 0.8601784110069275    |     Total timesteps: 71215
# Episode 1499     |      Reward: 424.0     |     length: 424      |      Loss: 3.6566414833068848    |     Total timesteps: 71639
# Episode 1500     |      Reward: 106.0     |     length: 106      |      Loss: 0.7850961089134216    |     Total timesteps: 71745
# ======Model saved.======
# Episode 1501     |      Reward: 592.0     |     length: 592      |      Loss: 0.44365713000297546    |     Total timesteps: 72337
# Episode 1502     |      Reward: 179.0     |     length: 179      |      Loss: 2.013646364212036    |     Total timesteps: 72516
# Episode 1503     |      Reward: 359.0     |     length: 359      |      Loss: 0.42414456605911255    |     Total timesteps: 72875
# Episode 1504     |      Reward: 363.0     |     length: 363      |      Loss: 3.5447428226470947    |     Total timesteps: 73238
# Episode 1505     |      Reward: 98.0     |     length: 98      |      Loss: 4.788224697113037    |     Total timesteps: 73336
# Episode 1506     |      Reward: 239.0     |     length: 239      |      Loss: 5.926022052764893    |     Total timesteps: 73575
# Episode 1507     |      Reward: 653.0     |     length: 653      |      Loss: 11.851452827453613    |     Total timesteps: 74228
# Episode 1508     |      Reward: 107.0     |     length: 107      |      Loss: 2.543950080871582    |     Total timesteps: 74335
# Episode 1509     |      Reward: 226.0     |     length: 226      |      Loss: 0.4352837800979614    |     Total timesteps: 74561
# Episode 1510     |      Reward: 320.0     |     length: 320      |      Loss: 0.9198341369628906    |     Total timesteps: 74881
# Episode 1511     |      Reward: 193.0     |     length: 193      |      Loss: 7.208705425262451    |     Total timesteps: 75074
# Episode 1512     |      Reward: 323.0     |     length: 323      |      Loss: 0.4300105571746826    |     Total timesteps: 75397
# Episode 1513     |      Reward: 114.0     |     length: 114      |      Loss: 0.6622540354728699    |     Total timesteps: 75511
# Episode 1514     |      Reward: 625.0     |     length: 625      |      Loss: 1.8124868869781494    |     Total timesteps: 76136
# Episode 1515     |      Reward: 120.0     |     length: 120      |      Loss: 2.6389057636260986    |     Total timesteps: 76256
# Episode 1516     |      Reward: 302.0     |     length: 302      |      Loss: 0.5656204223632812    |     Total timesteps: 76558
# Episode 1517     |      Reward: 505.0     |     length: 505      |      Loss: 0.7866100072860718    |     Total timesteps: 77063
# Episode 1518     |      Reward: 251.0     |     length: 251      |      Loss: 0.4505611062049866    |     Total timesteps: 77314
# Episode 1519     |      Reward: 609.0     |     length: 609      |      Loss: 0.46089303493499756    |     Total timesteps: 77923
# Episode 1520     |      Reward: 265.0     |     length: 265      |      Loss: 0.8987089395523071    |     Total timesteps: 78188
# Episode 1521     |      Reward: 640.0     |     length: 640      |      Loss: 8.089153289794922    |     Total timesteps: 78828
# Episode 1522     |      Reward: 133.0     |     length: 133      |      Loss: 4.034903049468994    |     Total timesteps: 78961
# Episode 1523     |      Reward: 622.0     |     length: 622      |      Loss: 0.4250226318836212    |     Total timesteps: 79583
# Episode 1524     |      Reward: 165.0     |     length: 165      |      Loss: 9.465886116027832    |     Total timesteps: 79748
# Episode 1525     |      Reward: 154.0     |     length: 154      |      Loss: 0.5587019920349121    |     Total timesteps: 79902
# Episode 1526     |      Reward: 331.0     |     length: 331      |      Loss: 8.873785972595215    |     Total timesteps: 80233
# Episode 1527     |      Reward: 356.0     |     length: 356      |      Loss: 0.40157127380371094    |     Total timesteps: 80589
# Episode 1528     |      Reward: 459.0     |     length: 459      |      Loss: 0.44566524028778076    |     Total timesteps: 81048
# Episode 1529     |      Reward: 236.0     |     length: 236      |      Loss: 0.5432553887367249    |     Total timesteps: 81284
# Episode 1530     |      Reward: 597.0     |     length: 597      |      Loss: 14.749921798706055    |     Total timesteps: 81881
# Episode 1531     |      Reward: 436.0     |     length: 436      |      Loss: 0.4795832633972168    |     Total timesteps: 82317
# Episode 1532     |      Reward: 192.0     |     length: 192      |      Loss: 0.3606296181678772    |     Total timesteps: 82509
# Episode 1533     |      Reward: 135.0     |     length: 135      |      Loss: 7.15092658996582    |     Total timesteps: 82644
# Episode 1534     |      Reward: 393.0     |     length: 393      |      Loss: 0.4129074811935425    |     Total timesteps: 83037
# Episode 1535     |      Reward: 803.0     |     length: 803      |      Loss: 0.45023900270462036    |     Total timesteps: 83840
# Episode 1536     |      Reward: 168.0     |     length: 168      |      Loss: 2.5781185626983643    |     Total timesteps: 84008
# Episode 1537     |      Reward: 164.0     |     length: 164      |      Loss: 0.3340182900428772    |     Total timesteps: 84172
# Episode 1538     |      Reward: 587.0     |     length: 587      |      Loss: 14.225638389587402    |     Total timesteps: 84759
# Episode 1539     |      Reward: 946.0     |     length: 946      |      Loss: 4.541529178619385    |     Total timesteps: 85705
# Episode 1540     |      Reward: 600.0     |     length: 600      |      Loss: 0.40088149905204773    |     Total timesteps: 86305
# Episode 1541     |      Reward: 320.0     |     length: 320      |      Loss: 4.5587382316589355    |     Total timesteps: 86625
# Episode 1542     |      Reward: 217.0     |     length: 217      |      Loss: 9.718067169189453    |     Total timesteps: 86842
# Episode 1543     |      Reward: 338.0     |     length: 338      |      Loss: 16.484874725341797    |     Total timesteps: 87180
# Episode 1544     |      Reward: 616.0     |     length: 616      |      Loss: 0.40147528052330017    |     Total timesteps: 87796
# Episode 1545     |      Reward: 155.0     |     length: 155      |      Loss: 10.310297012329102    |     Total timesteps: 87951
# Episode 1546     |      Reward: 248.0     |     length: 248      |      Loss: 15.469674110412598    |     Total timesteps: 88199
# Episode 1547     |      Reward: 551.0     |     length: 551      |      Loss: 5.3636698722839355    |     Total timesteps: 88750
# Episode 1548     |      Reward: 145.0     |     length: 145      |      Loss: 0.28532952070236206    |     Total timesteps: 88895
# Episode 1549     |      Reward: 172.0     |     length: 172      |      Loss: 0.31104928255081177    |     Total timesteps: 89067
# Episode 1550     |      Reward: 559.0     |     length: 559      |      Loss: 0.2549464702606201    |     Total timesteps: 89626
# Episode 1551     |      Reward: 359.0     |     length: 359      |      Loss: 0.39767181873321533    |     Total timesteps: 89985
# Episode 1552     |      Reward: 132.0     |     length: 132      |      Loss: 0.3648488521575928    |     Total timesteps: 90117
# Episode 1553     |      Reward: 541.0     |     length: 541      |      Loss: 16.317838668823242    |     Total timesteps: 90658
# Episode 1554     |      Reward: 808.0     |     length: 808      |      Loss: 15.021648406982422    |     Total timesteps: 91466
# Episode 1555     |      Reward: 340.0     |     length: 340      |      Loss: 0.4012739062309265    |     Total timesteps: 91806
# Episode 1556     |      Reward: 640.0     |     length: 640      |      Loss: 0.4597952663898468    |     Total timesteps: 92446
# Episode 1557     |      Reward: 608.0     |     length: 608      |      Loss: 0.3906342387199402    |     Total timesteps: 93054
# Episode 1558     |      Reward: 512.0     |     length: 512      |      Loss: 33.96464920043945    |     Total timesteps: 93566
# Episode 1559     |      Reward: 443.0     |     length: 443      |      Loss: 0.33768361806869507    |     Total timesteps: 94009
# Episode 1560     |      Reward: 195.0     |     length: 195      |      Loss: 48.029640197753906    |     Total timesteps: 94204
# Episode 1561     |      Reward: 192.0     |     length: 192      |      Loss: 0.3451295793056488    |     Total timesteps: 94396
# Episode 1562     |      Reward: 521.0     |     length: 521      |      Loss: 0.34637391567230225    |     Total timesteps: 94917
# Episode 1563     |      Reward: 521.0     |     length: 521      |      Loss: 2.54408860206604    |     Total timesteps: 95438
# Episode 1564     |      Reward: 1021.0     |     length: 1021      |      Loss: 83.50012969970703    |     Total timesteps: 96459
# Episode 1565     |      Reward: 191.0     |     length: 191      |      Loss: 0.430154025554657    |     Total timesteps: 96650
# Episode 1566     |      Reward: 342.0     |     length: 342      |      Loss: 0.29986611008644104    |     Total timesteps: 96992
# Episode 1567     |      Reward: 578.0     |     length: 578      |      Loss: 0.40602144598960876    |     Total timesteps: 97570
# Episode 1568     |      Reward: 230.0     |     length: 230      |      Loss: 0.27314338088035583    |     Total timesteps: 97800
# Episode 1569     |      Reward: 500.0     |     length: 500      |      Loss: 0.3648661971092224    |     Total timesteps: 98300
# Episode 1570     |      Reward: 462.0     |     length: 462      |      Loss: 2.5888092517852783    |     Total timesteps: 98762
# Episode 1571     |      Reward: 372.0     |     length: 372      |      Loss: 3.8154642581939697    |     Total timesteps: 99134
# Episode 1572     |      Reward: 178.0     |     length: 178      |      Loss: 0.3712434768676758    |     Total timesteps: 99312
# Episode 1573     |      Reward: 226.0     |     length: 226      |      Loss: 0.3828582465648651    |     Total timesteps: 99538
# Episode 1574     |      Reward: 256.0     |     length: 256      |      Loss: 0.5308279395103455    |     Total timesteps: 99794
# Episode 1575     |      Reward: 676.0     |     length: 676      |      Loss: 0.3852327764034271    |     Total timesteps: 100470
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
