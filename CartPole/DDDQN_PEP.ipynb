# %%
from torch import nn
import torch.nn.functional as F
import numpy as np
import gym

import torch
import json
import torch.nn as nn
import torch.nn.functional as F
from torch import nn, optim
import cv2
import os

import random                 # Handling random number generation
import time                   # Handling time calculation
from skimage import transform # Help us to preprocess the frames

from collections import deque # Ordered collection with ends
import matplotlib.pyplot as plt  # Display graphs

import warnings                  # This ignore all the warning messages that are normally printed during the training because of skiimage
warnings.filterwarnings('ignore')

# %%
### MODEL HYPERPARAMETERS
learning_rate =  0.00001     # Alpha (aka learning rate)

### TRAINING HYPERPARAMETERS
total_episodes = 100000         # Total episodes for training

batch_size = 128

# FIXED Q TARGETS HYPERPARAMETERS
max_tau = 1000 #Tau is the C step where we update our target network
update_steps = 4

# EXPLORATION HYPERPARAMETERS for epsilon greedy strategy
explore_start = 0.1           # exploration probability at start
explore_stop = 0.001            # minimum exploration probability        # exponential decay rate for exploration prob
explore = 20000

clip_norm = 0.00008

model_folder = f"./models/prioritised_replay/CN{clip_norm}_LR{learning_rate}_B{batch_size}"
os.makedirs(model_folder)
log_path = f"./logs/prioritised_replay/CN{clip_norm}_LR{learning_rate}_B{batch_size}.txt"

# Q LEARNING hyperparameters
gamma = 0.99               # Discounting rate

### MEMORY HYPERPARAMETERS
## If you have GPU change to 1million
pretrain_length = 1000             # Number of experiences stored in the Memory when initialized for the first time
memory_size = 50000 ##100000                 # Number of experiences the Memory can keep

env = gym.make('CartPole-v1')

# %%
class DDDQNet(nn.Module):
    def __init__(self):
        super().__init__()

        self.fc1 = nn.Linear(4, 64)
        self.relu = nn.ReLU()

        self.fc_value = nn.Linear(64, 256)
        self.value = nn.Linear(256, 1)

        self.fc_adv = nn.Linear(64, 256)
        self.adv = nn.Linear(256, 2)

    def forward(self, x):
        y = self.relu(self.fc1(x))
        value = self.relu(self.fc_value(y))
        adv = self.relu(self.fc_adv(y))

        value = self.value(value)
        adv = self.adv(adv)

        output = value + adv - torch.mean(adv, dim=1, keepdim=True)

        return output

    def select_action(self, x):
        with torch.no_grad():
            Q = self.forward(x)
            action_index = torch.argmax(Q, dim=1)
        return action_index.item()
    
class SumTree(object):
    """
    This SumTree code is modified version of Morvan Zhou: 
    https://github.com/MorvanZhou/Reinforcement-learning-with-tensorflow/blob/master/contents/5.2_Prioritized_Replay_DQN/RL_brain.py
    """
    data_pointer = 0
    
    """
    Here we initialize the tree with all nodes = 0, and initialize the data with all values = 0
    """
    def __init__(self, capacity):
        self.capacity = capacity # Number of leaf nodes (final nodes) that contains experiences
        
        # Generate the tree with all nodes values = 0
        # To understand this calculation (2 * capacity - 1) look at the schema above
        # Remember we are in a binary node (each node has max 2 children) so 2x size of leaf (capacity) - 1 (root node)
        # Parent nodes = capacity - 1
        # Leaf nodes = capacity
        self.tree = np.zeros(2 * capacity - 1)
        
        """ tree:
            0
           / \
          0   0
         / \ / \
        0  0 0  0  [Size: capacity] it's at this line that there is the priorities score (aka pi)
        """
        
        # Contains the experiences (so the size of data is capacity)
        self.data = np.zeros(capacity, dtype=object)
    
    
    """
    Here we add our priority score in the sumtree leaf and add the experience in data
    """
    def add(self, priority, data):
        # Look at what index we want to put the experience
        tree_index = self.data_pointer + self.capacity - 1
        
        """ tree:
            0
           / \
          0   0
         / \ / \
tree_index  0 0  0  We fill the leaves from left to right
        """
        
        # Update data frame
        self.data[self.data_pointer] = data
        
        # Update the leaf
        self.update (tree_index, priority)
        
        # Add 1 to data_pointer
        self.data_pointer += 1
        
        if self.data_pointer >= self.capacity:  # If we're above the capacity, you go back to first index (we overwrite)
            self.data_pointer = 0
            
    
    """
    Update the leaf priority score and propagate the change through tree
    """
    def update(self, tree_index, priority):
        # Change = new priority score - former priority score
        change = priority - self.tree[tree_index]
        self.tree[tree_index] = priority
        
        # then propagate the change through tree
        while tree_index != 0:    # this method is faster than the recursive loop in the reference code
            
            """
            Here we want to access the line above
            THE NUMBERS IN THIS TREE ARE THE INDEXES NOT THE PRIORITY VALUES
            
                0
               / \
              1   2
             / \ / \
            3  4 5  [6] 
            
            If we are in leaf at index 6, we updated the priority score
            We need then to update index 2 node
            So tree_index = (tree_index - 1) // 2
            tree_index = (6-1)//2
            tree_index = 2 (because // round the result)
            """
            tree_index = (tree_index - 1) // 2
            self.tree[tree_index] += change
    
    
    """
    Here we get the leaf_index, priority value of that leaf and experience associated with that index
    """
    def get_leaf(self, v):
        """
        Tree structure and array storage:
        Tree index:
             0         -> storing priority sum
            / \
          1     2
         / \   / \
        3   4 5   6    -> storing priority for experiences
        Array type for storing:
        [0,1,2,3,4,5,6]
        """
        parent_index = 0
        
        while True: # the while loop is faster than the method in the reference code
            left_child_index = 2 * parent_index + 1
            right_child_index = left_child_index + 1
            
            # If we reach bottom, end the search
            if left_child_index >= len(self.tree):
                leaf_index = parent_index
                break
            
            else: # downward search, always search for a higher priority node
                
                if v <= self.tree[left_child_index]:
                    parent_index = left_child_index
                    
                else:
                    v -= self.tree[left_child_index]
                    parent_index = right_child_index
            
        data_index = leaf_index - self.capacity + 1

        return leaf_index, self.tree[leaf_index], self.data[data_index]
    
    @property
    def total_priority(self):
        return self.tree[0] # Returns the root node
    
class Memory(object):  # stored as ( s, a, r, s_ ) in SumTree
    """
    This SumTree code is modified version and the original code is from:
    https://github.com/jaara/AI-blog/blob/master/Seaquest-DDQN-PER.py
    """
    PER_e = 0.01  # Hyperparameter that we use to avoid some experiences to have 0 probability of being taken
    PER_a = 0.6  # Hyperparameter that we use to make a tradeoff between taking only exp with high priority and sampling randomly
    PER_b = 0.4  # importance-sampling, from initial value increasing to 1
    
    PER_b_increment_per_sampling = 0.001
    
    absolute_error_upper = 1.  # clipped abs error

    def __init__(self, capacity):
        # Making the tree 
        """
        Remember that our tree is composed of a sum tree that contains the priority scores at his leaf
        And also a data array
        We don't use deque because it means that at each timestep our experiences change index by one.
        We prefer to use a simple array and to overwrite when the memory is full.
        """
        self.tree = SumTree(capacity)
        
    """
    Store a new experience in our tree
    Each new experience have a score of max_prority (it will be then improved when we use this exp to train our DDQN)
    """
    def store(self, experience):
        # Find the max priority
        max_priority = np.max(self.tree.tree[-self.tree.capacity:])
        
        # If the max priority = 0 we can't put priority = 0 since this exp will never have a chance to be selected
        # So we use a minimum priority
        if max_priority == 0:
            max_priority = self.absolute_error_upper
        
        self.tree.add(max_priority, experience)   # set the max p for new p

        
    """
    - First, to sample a minibatch of k size, the range [0, priority_total] is / into k ranges.
    - Then a value is uniformly sampled from each range
    - We search in the sumtree, the experience where priority score correspond to sample values are retrieved from.
    - Then, we calculate IS weights for each minibatch element
    """
    def sample(self, n):
        # Create a sample array that will contains the minibatch
        memory_b = []
        
        b_idx, b_ISWeights = np.empty((n,), dtype=np.int32), np.empty((n, 1), dtype=np.float32)
        
        # Calculate the priority segment
        # Here, as explained in the paper, we divide the Range[0, ptotal] into n ranges
        priority_segment = self.tree.total_priority / n       # priority segment
    
        # Here we increasing the PER_b each time we sample a new minibatch
        self.PER_b = np.min([1., self.PER_b + self.PER_b_increment_per_sampling])  # max = 1
        
        # Calculating the max_weight
        p_min = np.min(self.tree.tree[-self.tree.capacity:]) / self.tree.total_priority
        max_weight = (p_min * n) ** (-self.PER_b)
        
        for i in range(n):
            """
            A value is uniformly sample from each range
            """
            a, b = priority_segment * i, priority_segment * (i + 1)
            value = np.random.uniform(a, b)
            
            """
            Experience that correspond to each value is retrieved
            """
            index, priority, data = self.tree.get_leaf(value)
            
            #P(j)
            sampling_probabilities = priority / self.tree.total_priority
            
            #  IS = (1/N * 1/P(i))**b /max wi == (N*P(i))**-b  /max wi
            b_ISWeights[i, 0] = np.power(n * sampling_probabilities, -self.PER_b)/ max_weight
                                   
            b_idx[i]= index
            
            experience = [data]
            
            memory_b.append(experience)
        
        return b_idx, memory_b, b_ISWeights
    
    """
    Update the priorities on the tree
    """
    def batch_update(self, tree_idx, abs_errors):
        abs_errors += self.PER_e  # convert to abs and avoid 0
        clipped_errors = np.minimum(abs_errors, self.absolute_error_upper)
        ps = np.power(clipped_errors, self.PER_a)

        for ti, p in zip(tree_idx, ps):
            self.tree.update(ti, p)


def update_target_params(PolicyNetwork, TargetNetwork):
    """
    Copy parameters of the Policy network to Target network.
    """
    TargetNetwork_state_dict = TargetNetwork.state_dict()
    PolicyNetwork_state_dict = PolicyNetwork.state_dict()
    for key in PolicyNetwork_state_dict:
        TargetNetwork_state_dict[key] = PolicyNetwork_state_dict[key]
        TargetNetwork.load_state_dict(TargetNetwork_state_dict)

    return PolicyNetwork, TargetNetwork

# %%
import random
# Instantiate memory
memory = Memory(memory_size)
import numpy as np 
from skimage import transform

env = gym.make('CartPole-v1')
n_state = env.observation_space.shape[0]  # 4
n_action = env.action_space.n

state, _ = env.reset()


for i in range(pretrain_length):
    
    action = random.randint(0,1)
    next_state, reward, done, _, _ = env.step(action)

    if done:
        next_state = np.zeros(n_state)
        experience = state, action, reward, next_state, done
        #print("shape of a stack frame of dead: ", state.shape)
        memory.store(experience)
        
        # Start a new episode
        state, _ = env.reset()
    else:
        experience = state, action, reward, next_state, done
        memory.store(experience)

        state = next_state

env.close()

# %%
# Instantiate the DQNetwork
PolicyNetwork = DDDQNet()

# Instantiate the target network
TargetNetwork = DDDQNet()

optimizer = optim.RMSprop(PolicyNetwork.parameters(), lr=learning_rate)

def select_action(epsilon, state):
    """
    This function will do the part
    With ϵ select a random action atat, otherwise select at=argmaxaQ(st,a)

    Input state is 4 stacked states. 
    """

    num = random.random()

    if (num < epsilon):
        action = random.randint(0, 1)
        return action
    # Greedy action
    else:
        
        tensor_state = torch.tensor(state, dtype=torch.float32).unsqueeze(0)
        action = PolicyNetwork.select_action(tensor_state)
        return action

epsilon = explore_start
# Set Target network params
PolicyNetwork, TargetNetwork = update_target_params(PolicyNetwork, TargetNetwork)

out_f = open(log_path, 'w')

env = gym.make('CartPole-v1')

total_steps = 0

for episode in range(total_episodes):

    episode_step = 0
    episode_reward = 0
    state, _ = env.reset()
    # print("state: ", state)
    

    for time_steps in range(10000):

        episode_step += 1
        total_steps += 1

        action = select_action(epsilon, state)
        next_state, reward, done, _, _ = env.step(action)

        episode_reward += reward

        if done: 
            next_state = np.zeros(n_state)
            experience = state, action, reward, next_state, done
            memory.store(experience)

        else: 
            experience = state, action, reward, next_state, done
            # print("state: ", state)
            memory.store(experience)
            state = next_state


        tree_idx, batch, ISWeights_mb = memory.sample(batch_size)
        
        batch_states = torch.FloatTensor([each[0][0] for each in batch] )

        batch_actions = torch.FloatTensor([each[0][1] for each in batch]).unsqueeze(1)
        batch_rewards = torch.FloatTensor([each[0][2] for each in batch]).unsqueeze(1)
        batch_next_states = torch.FloatTensor([each[0][3] for each in batch] ) # stacked frames of np arrays 
        batch_dones = torch.FloatTensor([each[0][4] for each in batch]).unsqueeze(1)

        actions_index = batch_actions.detach().numpy().flatten()

        with torch.no_grad():
            policy_q_next = PolicyNetwork(batch_next_states)
            target_q_next = TargetNetwork(batch_next_states)
            online_max_action = torch.argmax(policy_q_next, dim=1, keepdim=True)
            y = batch_rewards + (1 - batch_dones) * gamma * target_q_next.gather(1, online_max_action.long())

        loss = F.mse_loss(PolicyNetwork(batch_states).gather(1, batch_actions.long()), y)
        optimizer.zero_grad()
        loss.backward()
        # torch.nn.utils.clip_grad_value_(PolicyNetwork.parameters(), clip)
        torch.nn.utils.clip_grad_norm_(PolicyNetwork.parameters(), clip_norm)
        optimizer.step()

        terminal_np = batch_dones.detach().numpy().flatten()
        policy_q_next_np = policy_q_next.detach().numpy()
        target_q_next_np = target_q_next.detach().numpy()
        rewards_np = batch_rewards.detach().numpy().flatten()

        target_qs_batch = []

        for i in range(0, len(batch)):

            terminal = terminal_np[i]
            action = np.argmax(policy_q_next_np[i])

            if terminal:
                target_qs_batch.append(torch.tensor(rewards_np[i], dtype=torch.float32)) # rewards_mb[i] is a TENSOR

            else: 
                target = rewards_np[i] + gamma * target_q_next_np[i][action]

                target_qs_batch.append(torch.tensor(target, dtype=torch.float32))

        ACTIONS = [torch.tensor(np.array([0,1]), dtype=torch.float32), torch.tensor(np.array([1,0]), dtype=torch.float32)]
        predicted_qs = [torch.sum(torch.mul(policy_q_next[i], ACTIONS[int(actions_index[i])])) for i in range(batch_size)]

        absolute_errors = [torch.abs(torch.subtract(predicted_qs[i], target_qs_batch[i])) for i in range(batch_size)]
        
        absolute_errors_np = np.array([error.item() for error in absolute_errors])
        ISWeights_list = ISWeights_mb.tolist()
        memory.batch_update(tree_idx, absolute_errors_np)


        if epsilon > explore_stop:
            epsilon -= (explore_start - explore_stop) / explore

        # print("POLICY PARAMS: " , PolicyNetwork.state_dict())
        if total_steps % update_steps == 0:
            PolicyNetwork, TargetNetwork = update_target_params(PolicyNetwork, TargetNetwork)
            # print("Model updated")

        if done: 
            # Write batch stats to log files 
            loss_at_end_of_episode = torch.mean(torch.stack(absolute_errors), dim=0).item()

            out_f.write(json.dumps({
                'episode': episode,
                'reward': episode_reward,
                'total_steps': total_steps,
                'length': episode_step,
                'loss': loss_at_end_of_episode,
                'epsilon': epsilon,
            }) + '\n')

            out_f.flush()
            

            print(f"Episode {episode}     |      Reward: {episode_reward}     |     length: {episode_step}      |      Loss: {loss_at_end_of_episode}    |     Total timesteps: {total_steps}")
        
            if episode % 100 == 0:
                torch.save(PolicyNetwork, f"{model_folder}/E_{episode}.pt")
                print(f"======Model saved.======")
            
            break

    if total_steps > 200000:
        break


env.close()
# Out:
# Episode 0     |      Reward: 9.0     |     length: 9      |      Loss: 1.0588138103485107    |     Total timesteps: 9
# ======Model saved.======
# Episode 1     |      Reward: 10.0     |     length: 10      |      Loss: 1.052673101425171    |     Total timesteps: 19
# Episode 2     |      Reward: 10.0     |     length: 10      |      Loss: 1.0533616542816162    |     Total timesteps: 29
# Episode 3     |      Reward: 12.0     |     length: 12      |      Loss: 1.0542298555374146    |     Total timesteps: 41
# Episode 4     |      Reward: 8.0     |     length: 8      |      Loss: 1.0546270608901978    |     Total timesteps: 49
# Episode 5     |      Reward: 9.0     |     length: 9      |      Loss: 1.0591225624084473    |     Total timesteps: 58
# Episode 6     |      Reward: 9.0     |     length: 9      |      Loss: 1.0598783493041992    |     Total timesteps: 67
# Episode 7     |      Reward: 9.0     |     length: 9      |      Loss: 1.0504741668701172    |     Total timesteps: 76
# Episode 8     |      Reward: 11.0     |     length: 11      |      Loss: 1.055037021636963    |     Total timesteps: 87
# Episode 9     |      Reward: 10.0     |     length: 10      |      Loss: 1.0726734399795532    |     Total timesteps: 97
# Episode 10     |      Reward: 8.0     |     length: 8      |      Loss: 1.0735135078430176    |     Total timesteps: 105
# Episode 11     |      Reward: 9.0     |     length: 9      |      Loss: 1.0689184665679932    |     Total timesteps: 114
# Episode 12     |      Reward: 10.0     |     length: 10      |      Loss: 1.0683937072753906    |     Total timesteps: 124
# Episode 13     |      Reward: 10.0     |     length: 10      |      Loss: 1.089091420173645    |     Total timesteps: 134
# Episode 14     |      Reward: 10.0     |     length: 10      |      Loss: 1.0729405879974365    |     Total timesteps: 144
# Episode 15     |      Reward: 9.0     |     length: 9      |      Loss: 1.0892834663391113    |     Total timesteps: 153
# Episode 16     |      Reward: 9.0     |     length: 9      |      Loss: 1.103867530822754    |     Total timesteps: 162
# Episode 17     |      Reward: 9.0     |     length: 9      |      Loss: 1.1066977977752686    |     Total timesteps: 171
# Episode 18     |      Reward: 12.0     |     length: 12      |      Loss: 1.1115283966064453    |     Total timesteps: 183
# Episode 19     |      Reward: 10.0     |     length: 10      |      Loss: 1.1075637340545654    |     Total timesteps: 193
# Episode 20     |      Reward: 10.0     |     length: 10      |      Loss: 1.1147675514221191    |     Total timesteps: 203
# Episode 21     |      Reward: 12.0     |     length: 12      |      Loss: 1.126798152923584    |     Total timesteps: 215
# Episode 22     |      Reward: 10.0     |     length: 10      |      Loss: 1.137734055519104    |     Total timesteps: 225
# Episode 23     |      Reward: 11.0     |     length: 11      |      Loss: 1.115614891052246    |     Total timesteps: 236
# Episode 24     |      Reward: 9.0     |     length: 9      |      Loss: 1.1309126615524292    |     Total timesteps: 245
# Episode 25     |      Reward: 9.0     |     length: 9      |      Loss: 1.1358625888824463    |     Total timesteps: 254
# Episode 26     |      Reward: 8.0     |     length: 8      |      Loss: 1.1422988176345825    |     Total timesteps: 262
# Episode 27     |      Reward: 10.0     |     length: 10      |      Loss: 1.1466104984283447    |     Total timesteps: 272
# Episode 28     |      Reward: 10.0     |     length: 10      |      Loss: 1.139643907546997    |     Total timesteps: 282
# Episode 29     |      Reward: 8.0     |     length: 8      |      Loss: 1.1430463790893555    |     Total timesteps: 290
# Episode 30     |      Reward: 10.0     |     length: 10      |      Loss: 1.1437664031982422    |     Total timesteps: 300
# Episode 31     |      Reward: 10.0     |     length: 10      |      Loss: 1.1604479551315308    |     Total timesteps: 310
# Episode 32     |      Reward: 10.0     |     length: 10      |      Loss: 1.192516803741455    |     Total timesteps: 320
# Episode 33     |      Reward: 10.0     |     length: 10      |      Loss: 1.158447504043579    |     Total timesteps: 330
# Episode 34     |      Reward: 10.0     |     length: 10      |      Loss: 1.1752861738204956    |     Total timesteps: 340
# Episode 35     |      Reward: 8.0     |     length: 8      |      Loss: 1.1822679042816162    |     Total timesteps: 348
# Episode 36     |      Reward: 10.0     |     length: 10      |      Loss: 1.1901633739471436    |     Total timesteps: 358
# Episode 37     |      Reward: 10.0     |     length: 10      |      Loss: 1.211952567100525    |     Total timesteps: 368
# Episode 38     |      Reward: 9.0     |     length: 9      |      Loss: 1.2199605703353882    |     Total timesteps: 377
# Episode 39     |      Reward: 9.0     |     length: 9      |      Loss: 1.2006069421768188    |     Total timesteps: 386
# Episode 40     |      Reward: 10.0     |     length: 10      |      Loss: 1.2214996814727783    |     Total timesteps: 396
# Episode 41     |      Reward: 10.0     |     length: 10      |      Loss: 1.2516504526138306    |     Total timesteps: 406
# Episode 42     |      Reward: 9.0     |     length: 9      |      Loss: 1.205245018005371    |     Total timesteps: 415
# Episode 43     |      Reward: 10.0     |     length: 10      |      Loss: 1.2074066400527954    |     Total timesteps: 425
# Episode 44     |      Reward: 10.0     |     length: 10      |      Loss: 1.2178642749786377    |     Total timesteps: 435
# Episode 45     |      Reward: 10.0     |     length: 10      |      Loss: 1.219903588294983    |     Total timesteps: 445
# Episode 46     |      Reward: 10.0     |     length: 10      |      Loss: 1.2976126670837402    |     Total timesteps: 455
# Episode 47     |      Reward: 9.0     |     length: 9      |      Loss: 1.231569528579712    |     Total timesteps: 464
# Episode 48     |      Reward: 8.0     |     length: 8      |      Loss: 1.2596256732940674    |     Total timesteps: 472
# Episode 49     |      Reward: 8.0     |     length: 8      |      Loss: 1.2310104370117188    |     Total timesteps: 480
# Episode 50     |      Reward: 10.0     |     length: 10      |      Loss: 1.2617708444595337    |     Total timesteps: 490
# Episode 51     |      Reward: 11.0     |     length: 11      |      Loss: 1.274987816810608    |     Total timesteps: 501
# Episode 52     |      Reward: 9.0     |     length: 9      |      Loss: 1.2422994375228882    |     Total timesteps: 510
# Episode 53     |      Reward: 9.0     |     length: 9      |      Loss: 1.2999017238616943    |     Total timesteps: 519
# Episode 54     |      Reward: 11.0     |     length: 11      |      Loss: 1.322462558746338    |     Total timesteps: 530
# Episode 55     |      Reward: 11.0     |     length: 11      |      Loss: 1.266038417816162    |     Total timesteps: 541
# Episode 56     |      Reward: 9.0     |     length: 9      |      Loss: 1.3161308765411377    |     Total timesteps: 550
# Episode 57     |      Reward: 10.0     |     length: 10      |      Loss: 1.28300142288208    |     Total timesteps: 560
# Episode 58     |      Reward: 9.0     |     length: 9      |      Loss: 1.319830298423767    |     Total timesteps: 569
# Episode 59     |      Reward: 9.0     |     length: 9      |      Loss: 1.3071905374526978    |     Total timesteps: 578
# Episode 60     |      Reward: 9.0     |     length: 9      |      Loss: 1.3398691415786743    |     Total timesteps: 587
# Episode 61     |      Reward: 11.0     |     length: 11      |      Loss: 1.3344340324401855    |     Total timesteps: 598
# Episode 62     |      Reward: 9.0     |     length: 9      |      Loss: 1.306901216506958    |     Total timesteps: 607
# Episode 63     |      Reward: 10.0     |     length: 10      |      Loss: 1.3662688732147217    |     Total timesteps: 617
# Episode 64     |      Reward: 8.0     |     length: 8      |      Loss: 1.370635986328125    |     Total timesteps: 625
# Episode 65     |      Reward: 9.0     |     length: 9      |      Loss: 1.3851311206817627    |     Total timesteps: 634
# Episode 66     |      Reward: 11.0     |     length: 11      |      Loss: 1.3612278699874878    |     Total timesteps: 645
# Episode 67     |      Reward: 10.0     |     length: 10      |      Loss: 1.4289209842681885    |     Total timesteps: 655
# Episode 68     |      Reward: 10.0     |     length: 10      |      Loss: 1.4533261060714722    |     Total timesteps: 665
# Episode 69     |      Reward: 9.0     |     length: 9      |      Loss: 1.395249366760254    |     Total timesteps: 674
# Episode 70     |      Reward: 8.0     |     length: 8      |      Loss: 1.4150803089141846    |     Total timesteps: 682
# Episode 71     |      Reward: 11.0     |     length: 11      |      Loss: 1.422085165977478    |     Total timesteps: 693
# Episode 72     |      Reward: 10.0     |     length: 10      |      Loss: 1.381213665008545    |     Total timesteps: 703
# Episode 73     |      Reward: 9.0     |     length: 9      |      Loss: 1.4176383018493652    |     Total timesteps: 712
# Episode 74     |      Reward: 10.0     |     length: 10      |      Loss: 1.4290122985839844    |     Total timesteps: 722
# Episode 75     |      Reward: 9.0     |     length: 9      |      Loss: 1.4137067794799805    |     Total timesteps: 731
# Episode 76     |      Reward: 10.0     |     length: 10      |      Loss: 1.429029107093811    |     Total timesteps: 741
# Episode 77     |      Reward: 9.0     |     length: 9      |      Loss: 1.4282283782958984    |     Total timesteps: 750
# Episode 78     |      Reward: 10.0     |     length: 10      |      Loss: 1.4272973537445068    |     Total timesteps: 760
# Episode 79     |      Reward: 10.0     |     length: 10      |      Loss: 1.4923927783966064    |     Total timesteps: 770
# Episode 80     |      Reward: 8.0     |     length: 8      |      Loss: 1.4442155361175537    |     Total timesteps: 778
# Episode 81     |      Reward: 8.0     |     length: 8      |      Loss: 1.4911470413208008    |     Total timesteps: 786
# Episode 82     |      Reward: 9.0     |     length: 9      |      Loss: 1.543071985244751    |     Total timesteps: 795
# Episode 83     |      Reward: 9.0     |     length: 9      |      Loss: 1.4953258037567139    |     Total timesteps: 804
# Episode 84     |      Reward: 9.0     |     length: 9      |      Loss: 1.5318807363510132    |     Total timesteps: 813
# Episode 85     |      Reward: 8.0     |     length: 8      |      Loss: 1.4833099842071533    |     Total timesteps: 821
# Episode 86     |      Reward: 9.0     |     length: 9      |      Loss: 1.4676926136016846    |     Total timesteps: 830
# Episode 87     |      Reward: 12.0     |     length: 12      |      Loss: 1.5828180313110352    |     Total timesteps: 842
# Episode 88     |      Reward: 11.0     |     length: 11      |      Loss: 1.50856614112854    |     Total timesteps: 853
# Episode 89     |      Reward: 9.0     |     length: 9      |      Loss: 1.4922515153884888    |     Total timesteps: 862
# Episode 90     |      Reward: 9.0     |     length: 9      |      Loss: 1.5003376007080078    |     Total timesteps: 871
# Episode 91     |      Reward: 11.0     |     length: 11      |      Loss: 1.5477216243743896    |     Total timesteps: 882
# Episode 92     |      Reward: 9.0     |     length: 9      |      Loss: 1.5730016231536865    |     Total timesteps: 891
# Episode 93     |      Reward: 9.0     |     length: 9      |      Loss: 1.5327553749084473    |     Total timesteps: 900
# Episode 94     |      Reward: 9.0     |     length: 9      |      Loss: 1.5611952543258667    |     Total timesteps: 909
# Episode 95     |      Reward: 13.0     |     length: 13      |      Loss: 1.638838768005371    |     Total timesteps: 922
# Episode 96     |      Reward: 10.0     |     length: 10      |      Loss: 1.6149966716766357    |     Total timesteps: 932
# Episode 97     |      Reward: 9.0     |     length: 9      |      Loss: 1.5245697498321533    |     Total timesteps: 941
# Episode 98     |      Reward: 10.0     |     length: 10      |      Loss: 1.5449042320251465    |     Total timesteps: 951
# Episode 99     |      Reward: 9.0     |     length: 9      |      Loss: 1.5864132642745972    |     Total timesteps: 960
# Episode 100     |      Reward: 11.0     |     length: 11      |      Loss: 1.5910274982452393    |     Total timesteps: 971
# ======Model saved.======
# Episode 101     |      Reward: 11.0     |     length: 11      |      Loss: 1.577298879623413    |     Total timesteps: 982
# Episode 102     |      Reward: 15.0     |     length: 15      |      Loss: 1.6266354322433472    |     Total timesteps: 997
# Episode 103     |      Reward: 10.0     |     length: 10      |      Loss: 1.6516914367675781    |     Total timesteps: 1007
# Episode 104     |      Reward: 10.0     |     length: 10      |      Loss: 1.6044566631317139    |     Total timesteps: 1017
# Episode 105     |      Reward: 11.0     |     length: 11      |      Loss: 1.6917846202850342    |     Total timesteps: 1028
# Episode 106     |      Reward: 8.0     |     length: 8      |      Loss: 1.606956958770752    |     Total timesteps: 1036
# Episode 107     |      Reward: 10.0     |     length: 10      |      Loss: 1.627995491027832    |     Total timesteps: 1046
# Episode 108     |      Reward: 10.0     |     length: 10      |      Loss: 1.6683619022369385    |     Total timesteps: 1056
# Episode 109     |      Reward: 9.0     |     length: 9      |      Loss: 1.6971808671951294    |     Total timesteps: 1065
# Episode 110     |      Reward: 10.0     |     length: 10      |      Loss: 1.7241146564483643    |     Total timesteps: 1075
# Episode 111     |      Reward: 10.0     |     length: 10      |      Loss: 1.7132787704467773    |     Total timesteps: 1085
# Episode 112     |      Reward: 11.0     |     length: 11      |      Loss: 1.6313928365707397    |     Total timesteps: 1096
# Episode 113     |      Reward: 8.0     |     length: 8      |      Loss: 1.7086013555526733    |     Total timesteps: 1104
# Episode 114     |      Reward: 11.0     |     length: 11      |      Loss: 1.6890398263931274    |     Total timesteps: 1115
# Episode 115     |      Reward: 9.0     |     length: 9      |      Loss: 1.6966979503631592    |     Total timesteps: 1124
# Episode 116     |      Reward: 8.0     |     length: 8      |      Loss: 1.744816541671753    |     Total timesteps: 1132
# Episode 117     |      Reward: 8.0     |     length: 8      |      Loss: 1.6455345153808594    |     Total timesteps: 1140
# Episode 118     |      Reward: 9.0     |     length: 9      |      Loss: 1.728910207748413    |     Total timesteps: 1149
# Episode 119     |      Reward: 13.0     |     length: 13      |      Loss: 1.787264347076416    |     Total timesteps: 1162
# Episode 120     |      Reward: 13.0     |     length: 13      |      Loss: 1.7118422985076904    |     Total timesteps: 1175
# Episode 121     |      Reward: 9.0     |     length: 9      |      Loss: 1.761203408241272    |     Total timesteps: 1184
# Episode 122     |      Reward: 10.0     |     length: 10      |      Loss: 1.8417377471923828    |     Total timesteps: 1194
# Episode 123     |      Reward: 10.0     |     length: 10      |      Loss: 1.8550689220428467    |     Total timesteps: 1204
# Episode 124     |      Reward: 9.0     |     length: 9      |      Loss: 1.8497047424316406    |     Total timesteps: 1213
# Episode 125     |      Reward: 10.0     |     length: 10      |      Loss: 1.8395822048187256    |     Total timesteps: 1223
# Episode 126     |      Reward: 10.0     |     length: 10      |      Loss: 1.8022350072860718    |     Total timesteps: 1233
# Episode 127     |      Reward: 11.0     |     length: 11      |      Loss: 1.853165864944458    |     Total timesteps: 1244
# Episode 128     |      Reward: 8.0     |     length: 8      |      Loss: 1.8757978677749634    |     Total timesteps: 1252
# Episode 129     |      Reward: 9.0     |     length: 9      |      Loss: 1.799144983291626    |     Total timesteps: 1261
# Episode 130     |      Reward: 9.0     |     length: 9      |      Loss: 1.8464295864105225    |     Total timesteps: 1270
# Episode 131     |      Reward: 8.0     |     length: 8      |      Loss: 1.8991243839263916    |     Total timesteps: 1278
# Episode 132     |      Reward: 10.0     |     length: 10      |      Loss: 1.8028841018676758    |     Total timesteps: 1288
# Episode 133     |      Reward: 11.0     |     length: 11      |      Loss: 1.8035120964050293    |     Total timesteps: 1299
# Episode 134     |      Reward: 10.0     |     length: 10      |      Loss: 1.8056241273880005    |     Total timesteps: 1309
# Episode 135     |      Reward: 10.0     |     length: 10      |      Loss: 1.858406662940979    |     Total timesteps: 1319
# Episode 136     |      Reward: 11.0     |     length: 11      |      Loss: 1.9320976734161377    |     Total timesteps: 1330
# Episode 137     |      Reward: 11.0     |     length: 11      |      Loss: 1.8992457389831543    |     Total timesteps: 1341
# Episode 138     |      Reward: 10.0     |     length: 10      |      Loss: 1.9039702415466309    |     Total timesteps: 1351
# Episode 139     |      Reward: 10.0     |     length: 10      |      Loss: 1.9436302185058594    |     Total timesteps: 1361
# Episode 140     |      Reward: 12.0     |     length: 12      |      Loss: 1.9464139938354492    |     Total timesteps: 1373
# Episode 141     |      Reward: 8.0     |     length: 8      |      Loss: 1.8812494277954102    |     Total timesteps: 1381
# Episode 142     |      Reward: 8.0     |     length: 8      |      Loss: 1.8456748723983765    |     Total timesteps: 1389
# Episode 143     |      Reward: 8.0     |     length: 8      |      Loss: 2.012911558151245    |     Total timesteps: 1397
# Episode 144     |      Reward: 8.0     |     length: 8      |      Loss: 2.1377618312835693    |     Total timesteps: 1405
# Episode 145     |      Reward: 11.0     |     length: 11      |      Loss: 2.0049047470092773    |     Total timesteps: 1416
# Episode 146     |      Reward: 9.0     |     length: 9      |      Loss: 2.0119829177856445    |     Total timesteps: 1425
# Episode 147     |      Reward: 8.0     |     length: 8      |      Loss: 1.9780843257904053    |     Total timesteps: 1433
# Episode 148     |      Reward: 10.0     |     length: 10      |      Loss: 2.085921049118042    |     Total timesteps: 1443
# Episode 149     |      Reward: 9.0     |     length: 9      |      Loss: 2.0221409797668457    |     Total timesteps: 1452
# Episode 150     |      Reward: 8.0     |     length: 8      |      Loss: 1.9886462688446045    |     Total timesteps: 1460
# Episode 151     |      Reward: 8.0     |     length: 8      |      Loss: 2.1265902519226074    |     Total timesteps: 1468
# Episode 152     |      Reward: 10.0     |     length: 10      |      Loss: 1.9944987297058105    |     Total timesteps: 1478
# Episode 153     |      Reward: 9.0     |     length: 9      |      Loss: 2.107276439666748    |     Total timesteps: 1487
# Episode 154     |      Reward: 10.0     |     length: 10      |      Loss: 2.112309694290161    |     Total timesteps: 1497
# Episode 155     |      Reward: 10.0     |     length: 10      |      Loss: 2.0663390159606934    |     Total timesteps: 1507
# Episode 156     |      Reward: 10.0     |     length: 10      |      Loss: 2.0526695251464844    |     Total timesteps: 1517
# Episode 157     |      Reward: 11.0     |     length: 11      |      Loss: 2.1096813678741455    |     Total timesteps: 1528
# Episode 158     |      Reward: 9.0     |     length: 9      |      Loss: 2.057529926300049    |     Total timesteps: 1537
# Episode 159     |      Reward: 9.0     |     length: 9      |      Loss: 2.011604070663452    |     Total timesteps: 1546
# Episode 160     |      Reward: 10.0     |     length: 10      |      Loss: 2.1343700885772705    |     Total timesteps: 1556
# Episode 161     |      Reward: 10.0     |     length: 10      |      Loss: 2.125765800476074    |     Total timesteps: 1566
# Episode 162     |      Reward: 10.0     |     length: 10      |      Loss: 2.130161762237549    |     Total timesteps: 1576
# Episode 163     |      Reward: 10.0     |     length: 10      |      Loss: 2.182755470275879    |     Total timesteps: 1586
# Episode 164     |      Reward: 9.0     |     length: 9      |      Loss: 2.191272735595703    |     Total timesteps: 1595
# Episode 165     |      Reward: 10.0     |     length: 10      |      Loss: 2.15934419631958    |     Total timesteps: 1605
# Episode 166     |      Reward: 9.0     |     length: 9      |      Loss: 2.188915967941284    |     Total timesteps: 1614
# Episode 167     |      Reward: 12.0     |     length: 12      |      Loss: 2.2190394401550293    |     Total timesteps: 1626
# Episode 168     |      Reward: 10.0     |     length: 10      |      Loss: 2.1589841842651367    |     Total timesteps: 1636
# Episode 169     |      Reward: 12.0     |     length: 12      |      Loss: 2.1436712741851807    |     Total timesteps: 1648
# Episode 170     |      Reward: 9.0     |     length: 9      |      Loss: 2.2185044288635254    |     Total timesteps: 1657
# Episode 171     |      Reward: 9.0     |     length: 9      |      Loss: 2.297595500946045    |     Total timesteps: 1666
# Episode 172     |      Reward: 12.0     |     length: 12      |      Loss: 2.297121524810791    |     Total timesteps: 1678
# Episode 173     |      Reward: 12.0     |     length: 12      |      Loss: 2.3194029331207275    |     Total timesteps: 1690
# Episode 174     |      Reward: 10.0     |     length: 10      |      Loss: 2.3056254386901855    |     Total timesteps: 1700
# Episode 175     |      Reward: 11.0     |     length: 11      |      Loss: 2.3713767528533936    |     Total timesteps: 1711
# Episode 176     |      Reward: 11.0     |     length: 11      |      Loss: 2.2180614471435547    |     Total timesteps: 1722
# Episode 177     |      Reward: 8.0     |     length: 8      |      Loss: 2.126368522644043    |     Total timesteps: 1730
# Episode 178     |      Reward: 10.0     |     length: 10      |      Loss: 2.291633367538452    |     Total timesteps: 1740
# Episode 179     |      Reward: 10.0     |     length: 10      |      Loss: 2.4746925830841064    |     Total timesteps: 1750
# Episode 180     |      Reward: 9.0     |     length: 9      |      Loss: 2.419485330581665    |     Total timesteps: 1759
# Episode 181     |      Reward: 10.0     |     length: 10      |      Loss: 2.3076376914978027    |     Total timesteps: 1769
# Episode 182     |      Reward: 11.0     |     length: 11      |      Loss: 2.2847347259521484    |     Total timesteps: 1780
# Episode 183     |      Reward: 9.0     |     length: 9      |      Loss: 2.39957857131958    |     Total timesteps: 1789
# Episode 184     |      Reward: 11.0     |     length: 11      |      Loss: 2.4205188751220703    |     Total timesteps: 1800
# Episode 185     |      Reward: 9.0     |     length: 9      |      Loss: 2.317844867706299    |     Total timesteps: 1809
# Episode 186     |      Reward: 8.0     |     length: 8      |      Loss: 2.318995475769043    |     Total timesteps: 1817
# Episode 187     |      Reward: 10.0     |     length: 10      |      Loss: 2.507418155670166    |     Total timesteps: 1827
# Episode 188     |      Reward: 9.0     |     length: 9      |      Loss: 2.373972177505493    |     Total timesteps: 1836
# Episode 189     |      Reward: 9.0     |     length: 9      |      Loss: 2.357898235321045    |     Total timesteps: 1845
# Episode 190     |      Reward: 9.0     |     length: 9      |      Loss: 2.354336977005005    |     Total timesteps: 1854
# Episode 191     |      Reward: 8.0     |     length: 8      |      Loss: 2.453732967376709    |     Total timesteps: 1862
# Episode 192     |      Reward: 8.0     |     length: 8      |      Loss: 2.504676103591919    |     Total timesteps: 1870
# Episode 193     |      Reward: 12.0     |     length: 12      |      Loss: 2.5932981967926025    |     Total timesteps: 1882
# Episode 194     |      Reward: 9.0     |     length: 9      |      Loss: 2.4164810180664062    |     Total timesteps: 1891
# Episode 195     |      Reward: 9.0     |     length: 9      |      Loss: 2.645637035369873    |     Total timesteps: 1900
# Episode 196     |      Reward: 10.0     |     length: 10      |      Loss: 2.5441908836364746    |     Total timesteps: 1910
# Episode 197     |      Reward: 9.0     |     length: 9      |      Loss: 2.4714901447296143    |     Total timesteps: 1919
# Episode 198     |      Reward: 9.0     |     length: 9      |      Loss: 2.576245069503784    |     Total timesteps: 1928
# Episode 199     |      Reward: 11.0     |     length: 11      |      Loss: 2.5153608322143555    |     Total timesteps: 1939
# Episode 200     |      Reward: 10.0     |     length: 10      |      Loss: 2.4728355407714844    |     Total timesteps: 1949
# ======Model saved.======
# Episode 201     |      Reward: 11.0     |     length: 11      |      Loss: 2.4838967323303223    |     Total timesteps: 1960
# Episode 202     |      Reward: 8.0     |     length: 8      |      Loss: 2.514204263687134    |     Total timesteps: 1968
# Episode 203     |      Reward: 11.0     |     length: 11      |      Loss: 2.5839130878448486    |     Total timesteps: 1979
# Episode 204     |      Reward: 10.0     |     length: 10      |      Loss: 2.6771812438964844    |     Total timesteps: 1989
# Episode 205     |      Reward: 10.0     |     length: 10      |      Loss: 2.5583930015563965    |     Total timesteps: 1999
# Episode 206     |      Reward: 11.0     |     length: 11      |      Loss: 2.4523792266845703    |     Total timesteps: 2010
# Episode 207     |      Reward: 10.0     |     length: 10      |      Loss: 2.7354907989501953    |     Total timesteps: 2020
# Episode 208     |      Reward: 9.0     |     length: 9      |      Loss: 2.4353201389312744    |     Total timesteps: 2029
# Episode 209     |      Reward: 10.0     |     length: 10      |      Loss: 2.4877665042877197    |     Total timesteps: 2039
# Episode 210     |      Reward: 11.0     |     length: 11      |      Loss: 2.642892837524414    |     Total timesteps: 2050
# Episode 211     |      Reward: 9.0     |     length: 9      |      Loss: 2.691610336303711    |     Total timesteps: 2059
# Episode 212     |      Reward: 8.0     |     length: 8      |      Loss: 2.5774950981140137    |     Total timesteps: 2067
# Episode 213     |      Reward: 10.0     |     length: 10      |      Loss: 2.681159734725952    |     Total timesteps: 2077
# Episode 214     |      Reward: 10.0     |     length: 10      |      Loss: 2.6308863162994385    |     Total timesteps: 2087
# Episode 215     |      Reward: 9.0     |     length: 9      |      Loss: 2.7214255332946777    |     Total timesteps: 2096
# Episode 216     |      Reward: 10.0     |     length: 10      |      Loss: 2.589067220687866    |     Total timesteps: 2106
# Episode 217     |      Reward: 13.0     |     length: 13      |      Loss: 2.7954177856445312    |     Total timesteps: 2119
# Episode 218     |      Reward: 8.0     |     length: 8      |      Loss: 2.8674674034118652    |     Total timesteps: 2127
# Episode 219     |      Reward: 9.0     |     length: 9      |      Loss: 2.739053726196289    |     Total timesteps: 2136
# Episode 220     |      Reward: 10.0     |     length: 10      |      Loss: 2.7968809604644775    |     Total timesteps: 2146
# Episode 221     |      Reward: 9.0     |     length: 9      |      Loss: 2.8336775302886963    |     Total timesteps: 2155
# Episode 222     |      Reward: 9.0     |     length: 9      |      Loss: 2.892613410949707    |     Total timesteps: 2164
# Episode 223     |      Reward: 10.0     |     length: 10      |      Loss: 2.8023033142089844    |     Total timesteps: 2174
# Episode 224     |      Reward: 11.0     |     length: 11      |      Loss: 2.881819009780884    |     Total timesteps: 2185
# Episode 225     |      Reward: 10.0     |     length: 10      |      Loss: 2.881946563720703    |     Total timesteps: 2195
# Episode 226     |      Reward: 9.0     |     length: 9      |      Loss: 2.9166195392608643    |     Total timesteps: 2204
# Episode 227     |      Reward: 9.0     |     length: 9      |      Loss: 2.7359912395477295    |     Total timesteps: 2213
# Episode 228     |      Reward: 12.0     |     length: 12      |      Loss: 2.678394079208374    |     Total timesteps: 2225
# Episode 229     |      Reward: 9.0     |     length: 9      |      Loss: 2.8410847187042236    |     Total timesteps: 2234
# Episode 230     |      Reward: 10.0     |     length: 10      |      Loss: 2.882019281387329    |     Total timesteps: 2244
# Episode 231     |      Reward: 9.0     |     length: 9      |      Loss: 2.8247880935668945    |     Total timesteps: 2253
# Episode 232     |      Reward: 9.0     |     length: 9      |      Loss: 3.083117961883545    |     Total timesteps: 2262
# Episode 233     |      Reward: 9.0     |     length: 9      |      Loss: 3.0108320713043213    |     Total timesteps: 2271
# Episode 234     |      Reward: 9.0     |     length: 9      |      Loss: 2.959501028060913    |     Total timesteps: 2280
# Episode 235     |      Reward: 10.0     |     length: 10      |      Loss: 3.057131052017212    |     Total timesteps: 2290
# Episode 236     |      Reward: 10.0     |     length: 10      |      Loss: 2.9020652770996094    |     Total timesteps: 2300
# Episode 237     |      Reward: 9.0     |     length: 9      |      Loss: 3.0692241191864014    |     Total timesteps: 2309
# Episode 238     |      Reward: 9.0     |     length: 9      |      Loss: 2.8928072452545166    |     Total timesteps: 2318
# Episode 239     |      Reward: 8.0     |     length: 8      |      Loss: 3.0514416694641113    |     Total timesteps: 2326
# Episode 240     |      Reward: 10.0     |     length: 10      |      Loss: 2.8854761123657227    |     Total timesteps: 2336
# Episode 241     |      Reward: 9.0     |     length: 9      |      Loss: 3.0210282802581787    |     Total timesteps: 2345
# Episode 242     |      Reward: 9.0     |     length: 9      |      Loss: 2.935967206954956    |     Total timesteps: 2354
# Episode 243     |      Reward: 11.0     |     length: 11      |      Loss: 3.141690254211426    |     Total timesteps: 2365
# Episode 244     |      Reward: 12.0     |     length: 12      |      Loss: 3.2111480236053467    |     Total timesteps: 2377
# Episode 245     |      Reward: 8.0     |     length: 8      |      Loss: 2.94932222366333    |     Total timesteps: 2385
# Episode 246     |      Reward: 13.0     |     length: 13      |      Loss: 3.1403279304504395    |     Total timesteps: 2398
# Episode 247     |      Reward: 14.0     |     length: 14      |      Loss: 3.0450074672698975    |     Total timesteps: 2412
# Episode 248     |      Reward: 10.0     |     length: 10      |      Loss: 2.921262502670288    |     Total timesteps: 2422
# Episode 249     |      Reward: 10.0     |     length: 10      |      Loss: 3.1804680824279785    |     Total timesteps: 2432
# Episode 250     |      Reward: 10.0     |     length: 10      |      Loss: 3.241534948348999    |     Total timesteps: 2442
# Episode 251     |      Reward: 9.0     |     length: 9      |      Loss: 3.287269353866577    |     Total timesteps: 2451
# Episode 252     |      Reward: 9.0     |     length: 9      |      Loss: 3.332327365875244    |     Total timesteps: 2460
# Episode 253     |      Reward: 9.0     |     length: 9      |      Loss: 3.17484712600708    |     Total timesteps: 2469
# Episode 254     |      Reward: 10.0     |     length: 10      |      Loss: 3.345546245574951    |     Total timesteps: 2479
# Episode 255     |      Reward: 9.0     |     length: 9      |      Loss: 3.286555290222168    |     Total timesteps: 2488
# Episode 256     |      Reward: 11.0     |     length: 11      |      Loss: 3.207684278488159    |     Total timesteps: 2499
# Episode 257     |      Reward: 11.0     |     length: 11      |      Loss: 3.2655632495880127    |     Total timesteps: 2510
# Episode 258     |      Reward: 11.0     |     length: 11      |      Loss: 3.1496987342834473    |     Total timesteps: 2521
# Episode 259     |      Reward: 9.0     |     length: 9      |      Loss: 3.205117702484131    |     Total timesteps: 2530
# Episode 260     |      Reward: 9.0     |     length: 9      |      Loss: 3.3458518981933594    |     Total timesteps: 2539
# Episode 261     |      Reward: 10.0     |     length: 10      |      Loss: 3.3639447689056396    |     Total timesteps: 2549
# Episode 262     |      Reward: 13.0     |     length: 13      |      Loss: 3.4663548469543457    |     Total timesteps: 2562
# Episode 263     |      Reward: 9.0     |     length: 9      |      Loss: 3.5621161460876465    |     Total timesteps: 2571
# Episode 264     |      Reward: 10.0     |     length: 10      |      Loss: 3.6467084884643555    |     Total timesteps: 2581
# Episode 265     |      Reward: 9.0     |     length: 9      |      Loss: 3.3980183601379395    |     Total timesteps: 2590
# Episode 266     |      Reward: 12.0     |     length: 12      |      Loss: 3.4022057056427    |     Total timesteps: 2602
# Episode 267     |      Reward: 13.0     |     length: 13      |      Loss: 3.3900649547576904    |     Total timesteps: 2615
# Episode 268     |      Reward: 9.0     |     length: 9      |      Loss: 3.390834093093872    |     Total timesteps: 2624
# Episode 269     |      Reward: 12.0     |     length: 12      |      Loss: 3.517996311187744    |     Total timesteps: 2636
# Episode 270     |      Reward: 9.0     |     length: 9      |      Loss: 3.477109432220459    |     Total timesteps: 2645
# Episode 271     |      Reward: 9.0     |     length: 9      |      Loss: 3.5859227180480957    |     Total timesteps: 2654
# Episode 272     |      Reward: 10.0     |     length: 10      |      Loss: 3.5397424697875977    |     Total timesteps: 2664
# Episode 273     |      Reward: 9.0     |     length: 9      |      Loss: 3.401181697845459    |     Total timesteps: 2673
# Episode 274     |      Reward: 9.0     |     length: 9      |      Loss: 3.7102110385894775    |     Total timesteps: 2682
# Episode 275     |      Reward: 11.0     |     length: 11      |      Loss: 3.5009500980377197    |     Total timesteps: 2693
# Episode 276     |      Reward: 9.0     |     length: 9      |      Loss: 3.7562484741210938    |     Total timesteps: 2702
# Episode 277     |      Reward: 9.0     |     length: 9      |      Loss: 3.5173051357269287    |     Total timesteps: 2711
# Episode 278     |      Reward: 10.0     |     length: 10      |      Loss: 3.5242090225219727    |     Total timesteps: 2721
# Episode 279     |      Reward: 12.0     |     length: 12      |      Loss: 3.651824712753296    |     Total timesteps: 2733
# Episode 280     |      Reward: 9.0     |     length: 9      |      Loss: 3.726346015930176    |     Total timesteps: 2742
# Episode 281     |      Reward: 9.0     |     length: 9      |      Loss: 3.6384949684143066    |     Total timesteps: 2751
# Episode 282     |      Reward: 10.0     |     length: 10      |      Loss: 3.7560274600982666    |     Total timesteps: 2761
# Episode 283     |      Reward: 10.0     |     length: 10      |      Loss: 3.651886224746704    |     Total timesteps: 2771
# Episode 284     |      Reward: 9.0     |     length: 9      |      Loss: 3.915487289428711    |     Total timesteps: 2780
# Episode 285     |      Reward: 9.0     |     length: 9      |      Loss: 3.6147499084472656    |     Total timesteps: 2789
# Episode 286     |      Reward: 8.0     |     length: 8      |      Loss: 3.6776342391967773    |     Total timesteps: 2797
# Episode 287     |      Reward: 9.0     |     length: 9      |      Loss: 3.9542527198791504    |     Total timesteps: 2806
# Episode 288     |      Reward: 10.0     |     length: 10      |      Loss: 3.7575881481170654    |     Total timesteps: 2816
# Episode 289     |      Reward: 10.0     |     length: 10      |      Loss: 3.7845494747161865    |     Total timesteps: 2826
# Episode 290     |      Reward: 9.0     |     length: 9      |      Loss: 4.057281494140625    |     Total timesteps: 2835
# Episode 291     |      Reward: 8.0     |     length: 8      |      Loss: 3.965198278427124    |     Total timesteps: 2843
# Episode 292     |      Reward: 11.0     |     length: 11      |      Loss: 4.0448102951049805    |     Total timesteps: 2854
# Episode 293     |      Reward: 10.0     |     length: 10      |      Loss: 3.920397996902466    |     Total timesteps: 2864
# Episode 294     |      Reward: 10.0     |     length: 10      |      Loss: 3.9986770153045654    |     Total timesteps: 2874
# Episode 295     |      Reward: 10.0     |     length: 10      |      Loss: 4.04776668548584    |     Total timesteps: 2884
# Episode 296     |      Reward: 10.0     |     length: 10      |      Loss: 4.050818920135498    |     Total timesteps: 2894
# Episode 297     |      Reward: 9.0     |     length: 9      |      Loss: 3.868405342102051    |     Total timesteps: 2903
# Episode 298     |      Reward: 10.0     |     length: 10      |      Loss: 4.014804840087891    |     Total timesteps: 2913
# Episode 299     |      Reward: 10.0     |     length: 10      |      Loss: 4.043182849884033    |     Total timesteps: 2923
# Episode 300     |      Reward: 8.0     |     length: 8      |      Loss: 4.038283348083496    |     Total timesteps: 2931
# ======Model saved.======
# Episode 301     |      Reward: 9.0     |     length: 9      |      Loss: 4.199094772338867    |     Total timesteps: 2940
# Episode 302     |      Reward: 10.0     |     length: 10      |      Loss: 4.122741222381592    |     Total timesteps: 2950
# Episode 303     |      Reward: 10.0     |     length: 10      |      Loss: 4.32231330871582    |     Total timesteps: 2960
# Episode 304     |      Reward: 11.0     |     length: 11      |      Loss: 4.037176132202148    |     Total timesteps: 2971
# Episode 305     |      Reward: 9.0     |     length: 9      |      Loss: 4.153903484344482    |     Total timesteps: 2980
# Episode 306     |      Reward: 10.0     |     length: 10      |      Loss: 4.073449611663818    |     Total timesteps: 2990
# Episode 307     |      Reward: 10.0     |     length: 10      |      Loss: 4.246193885803223    |     Total timesteps: 3000
# Episode 308     |      Reward: 11.0     |     length: 11      |      Loss: 4.177865982055664    |     Total timesteps: 3011
# Episode 309     |      Reward: 11.0     |     length: 11      |      Loss: 4.171582221984863    |     Total timesteps: 3022
# Episode 310     |      Reward: 12.0     |     length: 12      |      Loss: 4.170172214508057    |     Total timesteps: 3034
# Episode 311     |      Reward: 8.0     |     length: 8      |      Loss: 4.161282062530518    |     Total timesteps: 3042
# Episode 312     |      Reward: 8.0     |     length: 8      |      Loss: 4.121142387390137    |     Total timesteps: 3050
# Episode 313     |      Reward: 10.0     |     length: 10      |      Loss: 4.362411975860596    |     Total timesteps: 3060
# Episode 314     |      Reward: 10.0     |     length: 10      |      Loss: 4.202613353729248    |     Total timesteps: 3070
# Episode 315     |      Reward: 10.0     |     length: 10      |      Loss: 4.146236419677734    |     Total timesteps: 3080
# Episode 316     |      Reward: 10.0     |     length: 10      |      Loss: 4.228587627410889    |     Total timesteps: 3090
# Episode 317     |      Reward: 10.0     |     length: 10      |      Loss: 4.39286994934082    |     Total timesteps: 3100
# Episode 318     |      Reward: 9.0     |     length: 9      |      Loss: 4.22292947769165    |     Total timesteps: 3109
# Episode 319     |      Reward: 10.0     |     length: 10      |      Loss: 4.1724114418029785    |     Total timesteps: 3119
# Episode 320     |      Reward: 10.0     |     length: 10      |      Loss: 4.444481372833252    |     Total timesteps: 3129
# Episode 321     |      Reward: 10.0     |     length: 10      |      Loss: 4.363152503967285    |     Total timesteps: 3139
# Episode 322     |      Reward: 10.0     |     length: 10      |      Loss: 4.397074222564697    |     Total timesteps: 3149
# Episode 323     |      Reward: 10.0     |     length: 10      |      Loss: 4.141828536987305    |     Total timesteps: 3159
# Episode 324     |      Reward: 8.0     |     length: 8      |      Loss: 4.613977432250977    |     Total timesteps: 3167
# Episode 325     |      Reward: 9.0     |     length: 9      |      Loss: 4.411433219909668    |     Total timesteps: 3176
# Episode 326     |      Reward: 10.0     |     length: 10      |      Loss: 4.124485492706299    |     Total timesteps: 3186
# Episode 327     |      Reward: 9.0     |     length: 9      |      Loss: 4.444108486175537    |     Total timesteps: 3195
# Episode 328     |      Reward: 9.0     |     length: 9      |      Loss: 4.529013633728027    |     Total timesteps: 3204
# Episode 329     |      Reward: 9.0     |     length: 9      |      Loss: 4.496370315551758    |     Total timesteps: 3213
# Episode 330     |      Reward: 8.0     |     length: 8      |      Loss: 4.50800085067749    |     Total timesteps: 3221
# Episode 331     |      Reward: 10.0     |     length: 10      |      Loss: 4.292482376098633    |     Total timesteps: 3231
# Episode 332     |      Reward: 11.0     |     length: 11      |      Loss: 4.931931495666504    |     Total timesteps: 3242
# Episode 333     |      Reward: 10.0     |     length: 10      |      Loss: 4.553039073944092    |     Total timesteps: 3252
# Episode 334     |      Reward: 10.0     |     length: 10      |      Loss: 4.602003574371338    |     Total timesteps: 3262
# Episode 335     |      Reward: 10.0     |     length: 10      |      Loss: 4.442404270172119    |     Total timesteps: 3272
# Episode 336     |      Reward: 10.0     |     length: 10      |      Loss: 4.481932640075684    |     Total timesteps: 3282
# Episode 337     |      Reward: 12.0     |     length: 12      |      Loss: 4.60502815246582    |     Total timesteps: 3294
# Episode 338     |      Reward: 9.0     |     length: 9      |      Loss: 4.643772125244141    |     Total timesteps: 3303
# Episode 339     |      Reward: 10.0     |     length: 10      |      Loss: 4.614986419677734    |     Total timesteps: 3313
# Episode 340     |      Reward: 9.0     |     length: 9      |      Loss: 4.589397430419922    |     Total timesteps: 3322
# Episode 341     |      Reward: 9.0     |     length: 9      |      Loss: 4.362786769866943    |     Total timesteps: 3331
# Episode 342     |      Reward: 10.0     |     length: 10      |      Loss: 4.564990997314453    |     Total timesteps: 3341
# Episode 343     |      Reward: 9.0     |     length: 9      |      Loss: 4.500394821166992    |     Total timesteps: 3350
# Episode 344     |      Reward: 14.0     |     length: 14      |      Loss: 4.451075077056885    |     Total timesteps: 3364
# Episode 345     |      Reward: 10.0     |     length: 10      |      Loss: 4.73447322845459    |     Total timesteps: 3374
# Episode 346     |      Reward: 11.0     |     length: 11      |      Loss: 4.635989189147949    |     Total timesteps: 3385
# Episode 347     |      Reward: 9.0     |     length: 9      |      Loss: 4.342231273651123    |     Total timesteps: 3394
# Episode 348     |      Reward: 8.0     |     length: 8      |      Loss: 4.5710248947143555    |     Total timesteps: 3402
# Episode 349     |      Reward: 9.0     |     length: 9      |      Loss: 4.751102924346924    |     Total timesteps: 3411
# Episode 350     |      Reward: 10.0     |     length: 10      |      Loss: 4.713202476501465    |     Total timesteps: 3421
# Episode 351     |      Reward: 10.0     |     length: 10      |      Loss: 4.647630214691162    |     Total timesteps: 3431
# Episode 352     |      Reward: 9.0     |     length: 9      |      Loss: 4.8397979736328125    |     Total timesteps: 3440
# Episode 353     |      Reward: 10.0     |     length: 10      |      Loss: 4.605932712554932    |     Total timesteps: 3450
# Episode 354     |      Reward: 12.0     |     length: 12      |      Loss: 4.410946846008301    |     Total timesteps: 3462
# Episode 355     |      Reward: 10.0     |     length: 10      |      Loss: 4.751367568969727    |     Total timesteps: 3472
# Episode 356     |      Reward: 9.0     |     length: 9      |      Loss: 4.510395050048828    |     Total timesteps: 3481
# Episode 357     |      Reward: 11.0     |     length: 11      |      Loss: 4.821393966674805    |     Total timesteps: 3492
# Episode 358     |      Reward: 11.0     |     length: 11      |      Loss: 5.108079433441162    |     Total timesteps: 3503
# Episode 359     |      Reward: 9.0     |     length: 9      |      Loss: 4.564059257507324    |     Total timesteps: 3512
# Episode 360     |      Reward: 10.0     |     length: 10      |      Loss: 4.489628314971924    |     Total timesteps: 3522
# Episode 361     |      Reward: 10.0     |     length: 10      |      Loss: 4.444463729858398    |     Total timesteps: 3532
# Episode 362     |      Reward: 9.0     |     length: 9      |      Loss: 4.839897155761719    |     Total timesteps: 3541
# Episode 363     |      Reward: 9.0     |     length: 9      |      Loss: 4.718011379241943    |     Total timesteps: 3550
# Episode 364     |      Reward: 11.0     |     length: 11      |      Loss: 4.626049518585205    |     Total timesteps: 3561
# Episode 365     |      Reward: 8.0     |     length: 8      |      Loss: 4.614461898803711    |     Total timesteps: 3569
# Episode 366     |      Reward: 10.0     |     length: 10      |      Loss: 4.617066860198975    |     Total timesteps: 3579
# Episode 367     |      Reward: 9.0     |     length: 9      |      Loss: 4.606868743896484    |     Total timesteps: 3588
# Episode 368     |      Reward: 10.0     |     length: 10      |      Loss: 4.77274751663208    |     Total timesteps: 3598
# Episode 369     |      Reward: 8.0     |     length: 8      |      Loss: 4.725759029388428    |     Total timesteps: 3606
# Episode 370     |      Reward: 9.0     |     length: 9      |      Loss: 4.807611465454102    |     Total timesteps: 3615
# Episode 371     |      Reward: 8.0     |     length: 8      |      Loss: 4.49551248550415    |     Total timesteps: 3623
# Episode 372     |      Reward: 10.0     |     length: 10      |      Loss: 4.71668815612793    |     Total timesteps: 3633
# Episode 373     |      Reward: 11.0     |     length: 11      |      Loss: 4.732966899871826    |     Total timesteps: 3644
# Episode 374     |      Reward: 10.0     |     length: 10      |      Loss: 4.466552257537842    |     Total timesteps: 3654
# Episode 375     |      Reward: 11.0     |     length: 11      |      Loss: 4.7137017250061035    |     Total timesteps: 3665
# Episode 376     |      Reward: 8.0     |     length: 8      |      Loss: 4.756060600280762    |     Total timesteps: 3673
# Episode 377     |      Reward: 10.0     |     length: 10      |      Loss: 4.761066913604736    |     Total timesteps: 3683
# Episode 378     |      Reward: 10.0     |     length: 10      |      Loss: 4.792304992675781    |     Total timesteps: 3693
# Episode 379     |      Reward: 12.0     |     length: 12      |      Loss: 4.629958152770996    |     Total timesteps: 3705
# Episode 380     |      Reward: 10.0     |     length: 10      |      Loss: 4.677997589111328    |     Total timesteps: 3715
# Episode 381     |      Reward: 8.0     |     length: 8      |      Loss: 4.977409362792969    |     Total timesteps: 3723
# Episode 382     |      Reward: 10.0     |     length: 10      |      Loss: 4.8685760498046875    |     Total timesteps: 3733
# Episode 383     |      Reward: 8.0     |     length: 8      |      Loss: 4.7508134841918945    |     Total timesteps: 3741
# Episode 384     |      Reward: 9.0     |     length: 9      |      Loss: 4.448423385620117    |     Total timesteps: 3750
# Episode 385     |      Reward: 9.0     |     length: 9      |      Loss: 4.747787952423096    |     Total timesteps: 3759
# Episode 386     |      Reward: 11.0     |     length: 11      |      Loss: 4.863284111022949    |     Total timesteps: 3770
# Episode 387     |      Reward: 9.0     |     length: 9      |      Loss: 4.550234794616699    |     Total timesteps: 3779
# Episode 388     |      Reward: 10.0     |     length: 10      |      Loss: 4.615840911865234    |     Total timesteps: 3789
# ...
# Episode 4856     |      Reward: 16.0     |     length: 16      |      Loss: 16.923847198486328    |     Total timesteps: 186749
# Episode 4857     |      Reward: 18.0     |     length: 18      |      Loss: 15.092673301696777    |     Total timesteps: 186767
# Episode 4858     |      Reward: 22.0     |     length: 22      |      Loss: 21.239749908447266    |     Total timesteps: 186789
# Episode 4859     |      Reward: 19.0     |     length: 19      |      Loss: 20.304439544677734    |     Total timesteps: 186808
# Episode 4860     |      Reward: 19.0     |     length: 19      |      Loss: 22.812044143676758    |     Total timesteps: 186827
# Episode 4861     |      Reward: 17.0     |     length: 17      |      Loss: 18.331239700317383    |     Total timesteps: 186844
# Episode 4862     |      Reward: 21.0     |     length: 21      |      Loss: 18.649314880371094    |     Total timesteps: 186865
# Episode 4863     |      Reward: 24.0     |     length: 24      |      Loss: 25.787349700927734    |     Total timesteps: 186889
# Episode 4864     |      Reward: 23.0     |     length: 23      |      Loss: 17.80681610107422    |     Total timesteps: 186912
# Episode 4865     |      Reward: 25.0     |     length: 25      |      Loss: 18.56775665283203    |     Total timesteps: 186937
# Episode 4866     |      Reward: 22.0     |     length: 22      |      Loss: 13.477903366088867    |     Total timesteps: 186959
# Episode 4867     |      Reward: 22.0     |     length: 22      |      Loss: 22.656818389892578    |     Total timesteps: 186981
# Episode 4868     |      Reward: 22.0     |     length: 22      |      Loss: 30.455196380615234    |     Total timesteps: 187003
# Episode 4869     |      Reward: 21.0     |     length: 21      |      Loss: 9.494307518005371    |     Total timesteps: 187024
# Episode 4870     |      Reward: 24.0     |     length: 24      |      Loss: 15.628617286682129    |     Total timesteps: 187048
# Episode 4871     |      Reward: 19.0     |     length: 19      |      Loss: 28.37934112548828    |     Total timesteps: 187067
# Episode 4872     |      Reward: 20.0     |     length: 20      |      Loss: 19.453004837036133    |     Total timesteps: 187087
# Episode 4873     |      Reward: 25.0     |     length: 25      |      Loss: 17.215585708618164    |     Total timesteps: 187112
# Episode 4874     |      Reward: 15.0     |     length: 15      |      Loss: 22.51929473876953    |     Total timesteps: 187127
# Episode 4875     |      Reward: 18.0     |     length: 18      |      Loss: 15.779159545898438    |     Total timesteps: 187145
# Episode 4876     |      Reward: 26.0     |     length: 26      |      Loss: 25.508651733398438    |     Total timesteps: 187171
# Episode 4877     |      Reward: 20.0     |     length: 20      |      Loss: 22.848255157470703    |     Total timesteps: 187191
# Episode 4878     |      Reward: 18.0     |     length: 18      |      Loss: 16.157194137573242    |     Total timesteps: 187209
# Episode 4879     |      Reward: 21.0     |     length: 21      |      Loss: 16.132041931152344    |     Total timesteps: 187230
# Episode 4880     |      Reward: 21.0     |     length: 21      |      Loss: 19.61583137512207    |     Total timesteps: 187251
# Episode 4881     |      Reward: 32.0     |     length: 32      |      Loss: 26.401945114135742    |     Total timesteps: 187283
# Episode 4882     |      Reward: 31.0     |     length: 31      |      Loss: 26.026092529296875    |     Total timesteps: 187314
# Episode 4883     |      Reward: 20.0     |     length: 20      |      Loss: 13.816140174865723    |     Total timesteps: 187334
# Episode 4884     |      Reward: 28.0     |     length: 28      |      Loss: 19.693370819091797    |     Total timesteps: 187362
# Episode 4885     |      Reward: 25.0     |     length: 25      |      Loss: 25.96024513244629    |     Total timesteps: 187387
# Episode 4886     |      Reward: 23.0     |     length: 23      |      Loss: 20.1629695892334    |     Total timesteps: 187410
# Episode 4887     |      Reward: 27.0     |     length: 27      |      Loss: 22.017854690551758    |     Total timesteps: 187437
# Episode 4888     |      Reward: 26.0     |     length: 26      |      Loss: 26.43088150024414    |     Total timesteps: 187463
# Episode 4889     |      Reward: 21.0     |     length: 21      |      Loss: 21.390277862548828    |     Total timesteps: 187484
# Episode 4890     |      Reward: 32.0     |     length: 32      |      Loss: 23.02310562133789    |     Total timesteps: 187516
# Episode 4891     |      Reward: 25.0     |     length: 25      |      Loss: 24.757781982421875    |     Total timesteps: 187541
# Episode 4892     |      Reward: 33.0     |     length: 33      |      Loss: 19.31913185119629    |     Total timesteps: 187574
# Episode 4893     |      Reward: 32.0     |     length: 32      |      Loss: 20.78012466430664    |     Total timesteps: 187606
# Episode 4894     |      Reward: 30.0     |     length: 30      |      Loss: 18.55154037475586    |     Total timesteps: 187636
# Episode 4895     |      Reward: 39.0     |     length: 39      |      Loss: 23.132247924804688    |     Total timesteps: 187675
# Episode 4896     |      Reward: 39.0     |     length: 39      |      Loss: 14.728128433227539    |     Total timesteps: 187714
# Episode 4897     |      Reward: 32.0     |     length: 32      |      Loss: 27.693880081176758    |     Total timesteps: 187746
# Episode 4898     |      Reward: 31.0     |     length: 31      |      Loss: 15.356191635131836    |     Total timesteps: 187777
# Episode 4899     |      Reward: 34.0     |     length: 34      |      Loss: 18.90639305114746    |     Total timesteps: 187811
# Episode 4900     |      Reward: 47.0     |     length: 47      |      Loss: 25.097944259643555    |     Total timesteps: 187858
# ======Model saved.======
# Episode 4901     |      Reward: 39.0     |     length: 39      |      Loss: 17.560993194580078    |     Total timesteps: 187897
# Episode 4902     |      Reward: 39.0     |     length: 39      |      Loss: 17.702186584472656    |     Total timesteps: 187936
# Episode 4903     |      Reward: 34.0     |     length: 34      |      Loss: 12.776702880859375    |     Total timesteps: 187970
# Episode 4904     |      Reward: 53.0     |     length: 53      |      Loss: 17.25112533569336    |     Total timesteps: 188023
# Episode 4905     |      Reward: 43.0     |     length: 43      |      Loss: 16.085472106933594    |     Total timesteps: 188066
# Episode 4906     |      Reward: 38.0     |     length: 38      |      Loss: 18.10118865966797    |     Total timesteps: 188104
# Episode 4907     |      Reward: 50.0     |     length: 50      |      Loss: 21.77483367919922    |     Total timesteps: 188154
# Episode 4908     |      Reward: 43.0     |     length: 43      |      Loss: 20.116798400878906    |     Total timesteps: 188197
# Episode 4909     |      Reward: 47.0     |     length: 47      |      Loss: 23.453493118286133    |     Total timesteps: 188244
# Episode 4910     |      Reward: 47.0     |     length: 47      |      Loss: 18.249391555786133    |     Total timesteps: 188291
# Episode 4911     |      Reward: 58.0     |     length: 58      |      Loss: 23.53913116455078    |     Total timesteps: 188349
# Episode 4912     |      Reward: 49.0     |     length: 49      |      Loss: 16.177356719970703    |     Total timesteps: 188398
# Episode 4913     |      Reward: 62.0     |     length: 62      |      Loss: 9.947062492370605    |     Total timesteps: 188460
# Episode 4914     |      Reward: 58.0     |     length: 58      |      Loss: 15.753326416015625    |     Total timesteps: 188518
# Episode 4915     |      Reward: 53.0     |     length: 53      |      Loss: 19.456375122070312    |     Total timesteps: 188571
# Episode 4916     |      Reward: 54.0     |     length: 54      |      Loss: 13.09062671661377    |     Total timesteps: 188625
# Episode 4917     |      Reward: 69.0     |     length: 69      |      Loss: 17.934581756591797    |     Total timesteps: 188694
# Episode 4918     |      Reward: 57.0     |     length: 57      |      Loss: 11.717767715454102    |     Total timesteps: 188751
# Episode 4919     |      Reward: 51.0     |     length: 51      |      Loss: 14.0986967086792    |     Total timesteps: 188802
# Episode 4920     |      Reward: 67.0     |     length: 67      |      Loss: 14.749308586120605    |     Total timesteps: 188869
# Episode 4921     |      Reward: 61.0     |     length: 61      |      Loss: 16.382732391357422    |     Total timesteps: 188930
# Episode 4922     |      Reward: 61.0     |     length: 61      |      Loss: 19.372413635253906    |     Total timesteps: 188991
# Episode 4923     |      Reward: 63.0     |     length: 63      |      Loss: 18.28948211669922    |     Total timesteps: 189054
# Episode 4924     |      Reward: 59.0     |     length: 59      |      Loss: 9.981627464294434    |     Total timesteps: 189113
# Episode 4925     |      Reward: 83.0     |     length: 83      |      Loss: 27.713695526123047    |     Total timesteps: 189196
# Episode 4926     |      Reward: 68.0     |     length: 68      |      Loss: 18.788904190063477    |     Total timesteps: 189264
# Episode 4927     |      Reward: 84.0     |     length: 84      |      Loss: 27.327526092529297    |     Total timesteps: 189348
# Episode 4928     |      Reward: 87.0     |     length: 87      |      Loss: 9.040796279907227    |     Total timesteps: 189435
# Episode 4929     |      Reward: 97.0     |     length: 97      |      Loss: 22.034093856811523    |     Total timesteps: 189532
# Episode 4930     |      Reward: 81.0     |     length: 81      |      Loss: 21.93252944946289    |     Total timesteps: 189613
# Episode 4931     |      Reward: 78.0     |     length: 78      |      Loss: 22.073843002319336    |     Total timesteps: 189691
# Episode 4932     |      Reward: 105.0     |     length: 105      |      Loss: 18.17021942138672    |     Total timesteps: 189796
# Episode 4933     |      Reward: 108.0     |     length: 108      |      Loss: 23.456058502197266    |     Total timesteps: 189904
# Episode 4934     |      Reward: 110.0     |     length: 110      |      Loss: 22.036651611328125    |     Total timesteps: 190014
# Episode 4935     |      Reward: 97.0     |     length: 97      |      Loss: 16.581857681274414    |     Total timesteps: 190111
# Episode 4936     |      Reward: 101.0     |     length: 101      |      Loss: 16.84437370300293    |     Total timesteps: 190212
# Episode 4937     |      Reward: 97.0     |     length: 97      |      Loss: 18.060068130493164    |     Total timesteps: 190309
# Episode 4938     |      Reward: 127.0     |     length: 127      |      Loss: 15.893585205078125    |     Total timesteps: 190436
# Episode 4939     |      Reward: 136.0     |     length: 136      |      Loss: 13.918325424194336    |     Total timesteps: 190572
# Episode 4940     |      Reward: 134.0     |     length: 134      |      Loss: 17.917829513549805    |     Total timesteps: 190706
# Episode 4941     |      Reward: 150.0     |     length: 150      |      Loss: 13.734082221984863    |     Total timesteps: 190856
# Episode 4942     |      Reward: 183.0     |     length: 183      |      Loss: 14.812100410461426    |     Total timesteps: 191039
# Episode 4943     |      Reward: 130.0     |     length: 130      |      Loss: 18.945465087890625    |     Total timesteps: 191169
# Episode 4944     |      Reward: 171.0     |     length: 171      |      Loss: 9.572627067565918    |     Total timesteps: 191340
# Episode 4945     |      Reward: 214.0     |     length: 214      |      Loss: 17.181468963623047    |     Total timesteps: 191554
# Episode 4946     |      Reward: 162.0     |     length: 162      |      Loss: 17.8505916595459    |     Total timesteps: 191716
# Episode 4947     |      Reward: 221.0     |     length: 221      |      Loss: 21.692665100097656    |     Total timesteps: 191937
# Episode 4948     |      Reward: 276.0     |     length: 276      |      Loss: 20.57767677307129    |     Total timesteps: 192213
# Episode 4949     |      Reward: 199.0     |     length: 199      |      Loss: 14.810344696044922    |     Total timesteps: 192412
# Episode 4950     |      Reward: 186.0     |     length: 186      |      Loss: 19.959077835083008    |     Total timesteps: 192598
# Episode 4951     |      Reward: 187.0     |     length: 187      |      Loss: 15.148468971252441    |     Total timesteps: 192785
# Episode 4952     |      Reward: 240.0     |     length: 240      |      Loss: 20.399707794189453    |     Total timesteps: 193025
# Episode 4953     |      Reward: 187.0     |     length: 187      |      Loss: 17.5499267578125    |     Total timesteps: 193212
# Episode 4954     |      Reward: 205.0     |     length: 205      |      Loss: 12.749667167663574    |     Total timesteps: 193417
# Episode 4955     |      Reward: 250.0     |     length: 250      |      Loss: 19.017242431640625    |     Total timesteps: 193667
# Episode 4956     |      Reward: 249.0     |     length: 249      |      Loss: 12.400785446166992    |     Total timesteps: 193916
# Episode 4957     |      Reward: 211.0     |     length: 211      |      Loss: 13.04488468170166    |     Total timesteps: 194127
# Episode 4958     |      Reward: 326.0     |     length: 326      |      Loss: 16.727323532104492    |     Total timesteps: 194453
# Episode 4959     |      Reward: 223.0     |     length: 223      |      Loss: 16.885242462158203    |     Total timesteps: 194676
# Episode 4960     |      Reward: 170.0     |     length: 170      |      Loss: 11.944502830505371    |     Total timesteps: 194846
# Episode 4961     |      Reward: 325.0     |     length: 325      |      Loss: 13.888298988342285    |     Total timesteps: 195171
# Episode 4962     |      Reward: 235.0     |     length: 235      |      Loss: 19.10381317138672    |     Total timesteps: 195406
# Episode 4963     |      Reward: 186.0     |     length: 186      |      Loss: 13.525008201599121    |     Total timesteps: 195592
# Episode 4964     |      Reward: 251.0     |     length: 251      |      Loss: 16.925989151000977    |     Total timesteps: 195843
# Episode 4965     |      Reward: 257.0     |     length: 257      |      Loss: 15.53828239440918    |     Total timesteps: 196100
# Episode 4966     |      Reward: 271.0     |     length: 271      |      Loss: 12.881354331970215    |     Total timesteps: 196371
# Episode 4967     |      Reward: 207.0     |     length: 207      |      Loss: 16.518999099731445    |     Total timesteps: 196578
# Episode 4968     |      Reward: 305.0     |     length: 305      |      Loss: 16.7552547454834    |     Total timesteps: 196883
# Episode 4969     |      Reward: 311.0     |     length: 311      |      Loss: 18.11571502685547    |     Total timesteps: 197194
# Episode 4970     |      Reward: 199.0     |     length: 199      |      Loss: 16.791601181030273    |     Total timesteps: 197393
# Episode 4971     |      Reward: 257.0     |     length: 257      |      Loss: 17.70498275756836    |     Total timesteps: 197650
# Episode 4972     |      Reward: 287.0     |     length: 287      |      Loss: 15.189870834350586    |     Total timesteps: 197937
# Episode 4973     |      Reward: 289.0     |     length: 289      |      Loss: 9.756485939025879    |     Total timesteps: 198226
# Episode 4974     |      Reward: 410.0     |     length: 410      |      Loss: 14.068758964538574    |     Total timesteps: 198636
# Episode 4975     |      Reward: 367.0     |     length: 367      |      Loss: 15.315309524536133    |     Total timesteps: 199003
# Episode 4976     |      Reward: 251.0     |     length: 251      |      Loss: 14.100769996643066    |     Total timesteps: 199254
# Episode 4977     |      Reward: 265.0     |     length: 265      |      Loss: 16.897462844848633    |     Total timesteps: 199519
# Episode 4978     |      Reward: 449.0     |     length: 449      |      Loss: 12.90037727355957    |     Total timesteps: 199968
# Episode 4979     |      Reward: 267.0     |     length: 267      |      Loss: 12.680000305175781    |     Total timesteps: 200235
