# %% [markdown]
# ## 1. Getting VizDoom up and running

# %%
# import VizDoom for game env
from vizdoom import *
# Import random for action sampling
import random
# Import time for sleeping
import time
# import numpy for identity matrix
import numpy as np

from matplotlib import pyplot as plt

# %% [markdown]
# ## 2. Converting it to a Gym Environment

# %%
# Import environment base class from OpenAI Gym
from gymnasium import Env
# Import gym spaces
from gymnasium.spaces import Discrete, Box
# Import Opencv for greyscaling observations
import cv2

# Import environment checker
from stable_baselines3.common import env_checker
# Discrete(3).sample() returns a number from 0, 1, 2 -> used as index to select action
# Box(low=0, high=10, shape=(10,10)).sample() -> getting 10x10 array with low=0 and high=10

# %%
# Create VizDoom OpenAI Gym Environment
class VizDoomGym(Env): 
    def __init__(self, render=False):
        """
        Function called when we start the env.
        """

        # Inherit from Env
        super().__init__()
        
        # Set up game
        self.game = DoomGame()
        self.game.load_config('VizDoom/scenarios/defend_the_center.cfg')
        

        # Whether we want to render the game 
        if render == False:
            self.game.set_window_visible(False)
        else:
            self.game.set_window_visible(True)

        # Start the game
        self.game.init()
        
        # Create action space and observation space
        self.observation_space = Box(low=0, high=255, shape=(100, 160, 1), dtype=np.uint8)
        self.action_space = Discrete(3)

    
    def step(self, action):
        """
        How we take a step in the environment.
        """

        # Specify action and take step
        actions = np.identity(3, dtype=np.uint8)
        reward = self.game.make_action(actions[action], 4) # get action using index -> left, right, shoot
        
        # Get all the other stuff we need to return 
        if self.game.get_state():  # if nothing is
            state = self.game.get_state().screen_buffer
            state = self.grayscale(state)  # Apply Grayscale
            ammo = self.game.get_state().game_variables[0] 
            info = ammo
        # If we dont have anything turned from game.get_state
        else:
            # Return a numpy zero array
            state = np.zeros(self.observation_space.shape)
            # Return info (game variables) as zero
            info = 0

        info = {"info":info}
        done = self.game.is_episode_finished()
        truncated = False  # Assuming it's not truncated, modify if applicable
        
        return state, reward, done, truncated, info

    
    def render(self):
        """
        Define how to render the game environment.
        """
        pass

    
    def reset(self, seed=None):
        """
        Function for defining what happens when we start a new game.
        """
        if seed is not None:
            self.game.set_seed(seed)
            
        self.game.new_episode()
        state = self.game.get_state().screen_buffer  # Apply Grayscale

        return self.grayscale(state), {}

    
    def grayscale(self, observation):
        """
        Function to grayscale the game frame and resize it.
        observation: gameframe
        """
        # Change colour channels 
        gray = cv2.cvtColor(np.moveaxis(observation, 0, -1), cv2.COLOR_BGR2GRAY)

        # Reduce image pixel size for faster training
        resize = cv2.resize(gray, (160,100), interpolation=cv2.INTER_CUBIC)
        state = np.reshape(resize,(100, 160,1))
        return state

    def close(self):
        """
        Call to close down the game.
        """
        self.game.close()

# %%
env = VizDoomGym(render=True)

# %% [markdown]
# Environment checker

# %%
env_checker.check_env(env)

# %%
env.close()

# %% [markdown]
# ## 3. Setup Callback
# Save model at different state of training

# %%
# Import os for file nav
import os
# Import callback class from sb3
from stable_baselines3.common.callbacks import BaseCallback

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)
        return True

# %%
CHECKPOINT_DIR = './train/train_defend'
LOG_DIR = './logs/log_defend'

# %%
# Create instance of callback
callback = TrainAndLoggingCallback(check_freq=10000, save_path=CHECKPOINT_DIR) 
# after every 10000 steps of training the model, weights are saved for the pytorch agent

# %% [markdown]
# ## 5. Train Model

# %%
# Import PPO for training
from stable_baselines3 import PPO

# %%
# Non rendered environment
env = VizDoomGym()

# %%
# n_steps: How many steps/frames the agent is going to take and store in the buffer 
# before run through training of actor and critique
# ideally not too close to end of game (300) but somewhere close
model = PPO('CnnPolicy', env, tensorboard_log=LOG_DIR, verbose=1, learning_rate=0.0001, n_steps=4096)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=100000, callback=callback)
# Out:
# Logging to ./logs/log_defend/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81.3     |
# |    ep_rew_mean     | 0.24     |
# | time/              |          |
# |    fps             | 27       |
# |    iterations      | 1        |
# |    time_elapsed    | 147      |
# |    total_timesteps | 4096     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 88.1        |
# |    ep_rew_mean          | 0.848       |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 2           |
# |    time_elapsed         | 388         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011194703 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.0226     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0279      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00744    |
# |    value_loss           | 0.11        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97.3        |
# |    ep_rew_mean          | 1.6         |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 3           |
# |    time_elapsed         | 619         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011465379 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.335       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00988    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0203     |
# |    value_loss           | 0.137       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 107         |
# |    ep_rew_mean          | 2.34        |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 4           |
# |    time_elapsed         | 850         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011567032 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.541       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00968     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.027      |
# |    value_loss           | 0.147       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 112         |
# |    ep_rew_mean          | 2.9         |
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 5           |
# |    time_elapsed         | 1078        |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.014259594 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.994      |
# |    explained_variance   | 0.644       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00335     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0323     |
# |    value_loss           | 0.136       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 120         |
# |    ep_rew_mean          | 3.61        |
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 6           |
# |    time_elapsed         | 1313        |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.016600017 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.962      |
# |    explained_variance   | 0.71        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0121     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0362     |
# |    value_loss           | 0.161       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 124         |
# |    ep_rew_mean          | 4.22        |
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 7           |
# |    time_elapsed         | 1552        |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.017704241 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.927      |
# |    explained_variance   | 0.695       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0332     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0394     |
# |    value_loss           | 0.156       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 131        |
# |    ep_rew_mean          | 4.87       |
# | time/                   |            |
# |    fps                  | 18         |
# |    iterations           | 8          |
# |    time_elapsed         | 1790       |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.02094359 |
# |    clip_fraction        | 0.221      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.891     |
# |    explained_variance   | 0.757      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0288    |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0428    |
# |    value_loss           | 0.148      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 136         |
# |    ep_rew_mean          | 5.29        |
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 9           |
# |    time_elapsed         | 2035        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.021072503 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.881      |
# |    explained_variance   | 0.734       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0164     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0425     |
# |    value_loss           | 0.154       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 140         |
# |    ep_rew_mean          | 5.72        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 10          |
# |    time_elapsed         | 2275        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.019275934 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.865      |
# |    explained_variance   | 0.79        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0454     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0446     |
# |    value_loss           | 0.145       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 143         |
# |    ep_rew_mean          | 5.94        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 11          |
# |    time_elapsed         | 2516        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.020422028 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.83       |
# |    explained_variance   | 0.836       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.000911   |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0431     |
# |    value_loss           | 0.165       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 144         |
# |    ep_rew_mean          | 6.17        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 12          |
# |    time_elapsed         | 2759        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.024481071 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.799      |
# |    explained_variance   | 0.848       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0223     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0429     |
# |    value_loss           | 0.161       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 153         |
# |    ep_rew_mean          | 6.82        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 13          |
# |    time_elapsed         | 3002        |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.022447739 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.781      |
# |    explained_variance   | 0.861       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.000109    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0386     |
# |    value_loss           | 0.193       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 163         |
# |    ep_rew_mean          | 7.49        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 14          |
# |    time_elapsed         | 3269        |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.023205392 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.742      |
# |    explained_variance   | 0.87        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0289     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0373     |
# |    value_loss           | 0.192       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 171         |
# |    ep_rew_mean          | 8.24        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 15          |
# |    time_elapsed         | 3542        |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.024380608 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.684      |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00768    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0395     |
# |    value_loss           | 0.17        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 183         |
# |    ep_rew_mean          | 8.99        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 16          |
# |    time_elapsed         | 3814        |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.022595242 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.701      |
# |    explained_variance   | 0.9         |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00836    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0395     |
# |    value_loss           | 0.17        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 188         |
# |    ep_rew_mean          | 9.31        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 17          |
# |    time_elapsed         | 4089        |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.027731497 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.671      |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0107      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0416     |
# |    value_loss           | 0.146       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 189         |
# |    ep_rew_mean          | 9.51        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 18          |
# |    time_elapsed         | 4359        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.024659399 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00575    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0395     |
# |    value_loss           | 0.15        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 192         |
# |    ep_rew_mean          | 9.75        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 19          |
# |    time_elapsed         | 4625        |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.025395738 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.666      |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0117     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.04       |
# |    value_loss           | 0.128       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 192         |
# |    ep_rew_mean          | 9.85        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 20          |
# |    time_elapsed         | 4892        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.028871872 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.622      |
# |    explained_variance   | 0.954       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00318     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0377     |
# |    value_loss           | 0.135       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 199         |
# |    ep_rew_mean          | 10.4        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 21          |
# |    time_elapsed         | 5158        |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.030538429 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.564      |
# |    explained_variance   | 0.954       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00337    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0377     |
# |    value_loss           | 0.133       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 206         |
# |    ep_rew_mean          | 10.9        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 22          |
# |    time_elapsed         | 5425        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.029885974 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.518      |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0158     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0377     |
# |    value_loss           | 0.125       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 211         |
# |    ep_rew_mean          | 11.3        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 23          |
# |    time_elapsed         | 5675        |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.032245457 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.527      |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0237     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0379     |
# |    value_loss           | 0.123       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 213        |
# |    ep_rew_mean          | 11.5       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 24         |
# |    time_elapsed         | 5909       |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.03192791 |
# |    clip_fraction        | 0.209      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.517     |
# |    explained_variance   | 0.956      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0174    |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0364    |
# |    value_loss           | 0.121      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 216        |
# |    ep_rew_mean          | 11.8       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 25         |
# |    time_elapsed         | 6146       |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.02946965 |
# |    clip_fraction        | 0.207      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.55      |
# |    explained_variance   | 0.96       |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.000236  |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0365    |
# |    value_loss           | 0.112      |
# ----------------------------------------

# %% [markdown]
# ## 5. Test Model

# %%
# Import eval policy to test agent
from stable_baselines3.common.evaluation import evaluate_policy

# %%
# Reload model from disc
model = PPO.load('./train/train_defend/best_model_70000')

# %%
# Create rendered envrironment
env = VizDoomGym(render=True)

# %%
# Evaluate mean reward for 10 games
mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=10)
# Out:
# ---------------------------------------------------------------------------
# ViZDoomUnexpectedExitException            Traceback (most recent call last)
# Cell In[36], line 2
#       1 # Evaluate mean reward for 10 games
# ----> 2 mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=10)
#
# File ~/anaconda3/envs/pythonlab/lib/python3.8/site-packages/stable_baselines3/common/evaluation.py:94, in evaluate_policy(model, env, n_eval_episodes, deterministic, render, callback, reward_threshold, return_episode_rewards, warn)
#      87 while (episode_counts < episode_count_targets).any():
#      88     actions, states = model.predict(
#      89         observations,  # type: ignore[arg-type]
#      90         state=states,
#      91         episode_start=episode_starts,
#      92         deterministic=deterministic,
#      93     )
# ---> 94     new_observations, rewards, dones, infos = env.step(actions)
#      95     current_rewards += rewards
#      96     current_lengths += 1
#
# File ~/anaconda3/envs/pythonlab/lib/python3.8/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:206, in VecEnv.step(self, actions)
#     199 """
#     200 Step the environments with the given action
#     201
#     202 :param actions: the action
#     203 :return: observation, reward, done, information
#     204 """
#     205 self.step_async(actions)
# --> 206 return self.step_wait()
#
# File ~/anaconda3/envs/pythonlab/lib/python3.8/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# Cell In[8], line 37, in VizDoomGym.step(self, action)
#      35 # Specify action and take step
#      36 actions = np.identity(3, dtype=np.uint8)
# ---> 37 reward = self.game.make_action(actions[action], 4) # get action using index -> left, right, shoot
#      39 # Get all the other stuff we need to return
#      40 if self.game.get_state():  # if nothing is
#
# ViZDoomUnexpectedExitException: Controlled ViZDoom instance exited unexpectedly.

# %%
mean_reward
# Out:
# 6.0

# %%
for episode in range(5):
    total_reward = 0
    obs = env.reset()[0]
    done = False
    while not done:
        action, _ = model.predict(obs) # Use model to predict what action to take
        obs, reward, done, _, info = env.step(action) # take the predicted action
        time.sleep(0.25)
        total_reward += reward
    print('Total Reward for episode {} is {}'.format(total_reward, episode))
    time.sleep(2)
# Out:
# Total Reward for episode 5.0 is 0
# Total Reward for episode 12.0 is 1
# Total Reward for episode 6.0 is 2
# Total Reward for episode 10.0 is 3
# Total Reward for episode 10.0 is 4

# %%
env.close()
